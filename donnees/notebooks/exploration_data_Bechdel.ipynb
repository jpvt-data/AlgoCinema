# %% [markdown]
# # Ressources
# - Page GitHub du projet Data for Good
# https://github.com/dataforgoodfr/bechdelai
# - Documentation de l'API
# https://bechdeltest.com/api/v1/doc#getMovieByImdbId
# - Licence à citer dans README
# CC BY-NC 3.0 (https://creativecommons.org/licenses/by-nc/3.0/)
# Attribution-NonCommercial 3.0 Unported

# %% [markdown]
# # Étape 1 : Préparation et Importation des Données

# %%
# 1. Importer les bibliothèques nécessaires

import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2. Récupérer les données à partir de l'API

link = 'http://bechdeltest.com/api/v1/getAllMovies'


# Effectuer la requête GET

r = requests.get(link)


# Vérifier que la requête a réussi (code HTTP 200)
if r.status_code == 200:
    # Récupérer la réponse JSON
    data = r.json()

    print(f"Statut HTTP: {r.status_code}")
    print("Contenu de la réponse :", r.text)

# Enregistrer la réponse JSON dans un fichier
    file = '..\gitignore\dataforgood_bechdelai.json'
    with open(file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

    print("Données enregistrées dans 'gitignore\dataforgood_bechdelai.json'")
else:
    print(f"Erreur lors de la requête : {response.status_code}")
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\g'
# <>:24: SyntaxWarning: invalid escape sequence '\d'
# <>:20: SyntaxWarning: invalid escape sequence '\g'
# <>:24: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\jpvt\AppData\Local\Temp\ipykernel_8840\868025735.py:20: SyntaxWarning: invalid escape sequence '\g'
#   file = '..\gitignore\dataforgood_bechdelai.json'
# C:\Users\jpvt\AppData\Local\Temp\ipykernel_8840\868025735.py:24: SyntaxWarning: invalid escape sequence '\d'
#   print("Données enregistrées dans 'gitignore\dataforgood_bechdelai.json'")
# Statut HTTP: 200
# Contenu de la réponse : [{"rating":0,"id":9602,"imdbid":"3155794","title":"Passage de Venus","year":1874},{"rating":0,"imdbid":"14495706","id":9804,"title":"La Rosace Magique","year":1877},{"rating":0,"id":9603,"imdbid":"2221420","title":"Sallie Gardner at a Gallop","year":1878},{"year":1878,"title":"Le singe musicien","imdbid":"12592084","id":9806,"rating":0},{"year":1881,"title":"Athlete Swinging a Pick","id":9816,"imdbid":"7816420","rating":0},{"rating":0,"id":9831,"imdbid":"5459794","title":"Buffalo Running","year":1883},{"rating":0,"imdbid":"8588366","id":9832,"title":"L&#39;homme machine","year":1885},{"title":"Man Walking Around the Corner","year":1887,"rating":0,"imdbid":"2075247","id":9614},{"title":"Cockatoo Flying","year":1887,"rating":0,"imdbid":"8133192","id":9836},{"rating":0,"id":9837,"imdbid":"7411790","title":"Child Carrying Flowers to Woman","year":1887},{"title":"Jumping Over a Man&#39;s Back-Leapfrog","year":1887,"rating":0,"id":9838,"imdbid":"7541160"},{"title":"Man Riding Jumping Horse","year":1887,"rating":0,"imdbid":"7754902","id":9841},{"imdbid":"8361552","id":9902,"rating":0,"year":1887,"title":"Baboon Climbing a Pole"},{"id":8040,"imdbid":"0392728","rating":0,"year":1888,"title":"Roundhay Garden Scene"},{"year":1888,"title":"Accordion Player","imdbid":"1758563","id":9615,"rating":0},{"rating":0,"imdbid":"0343112","id":9616,"title":"Traffic Crossing Leeds Bridge","year":1888},{"title":"Pferd und Reiter Springen uber ein Hindernis","year":1888,"rating":0,"imdbid":"3274100","id":9675},{"title":"Brighton Street Scene","year":1888,"rating":0,"imdbid":"2116853","id":9947},{"rating":0,"id":9619,"imdbid":"0466876","title":"Leisurely Pedestrians, Open Topped Buses and Hansom Cabs with Trotting Horses","year":1889},{"title":"Hyde Park Corner","year":1889,"rating":0,"id":9945,"imdbid":"2116898"},{"year":1890,"title":"Monkeyshines, No. 1","imdbid":"0361921","id":9617,"rating":0},{"year":1890,"title":"Monkeyshines, No. 2","imdbid":"0416046","id":9618,"rating":0},{"rating":0,"imdbid":"1202028","id":9621,"title":"London&#39;s Trafalgar Square","year":1890},{"year":1890,"title":"Monkeyshines, No. 3","imdbid":"0416047","id":9678,"rating":0},{"year":1890,"title":"Mosquinha","id":9946,"imdbid":"5285442","rating":0},{"title":"Traffic in King&#39;s Road, Chelsea","year":1890,"rating":0,"imdbid":"2116968","id":9944},{"title":"Dickson Greeting","year":1891,"rating":0,"id":9626,"imdbid":"0241373"},{"id":9628,"imdbid":"0241715","rating":0,"year":1891,"title":"Men Boxing"},{"imdbid":"0241763","id":9629,"rating":0,"year":1891,"title":"Newark Athlete"},{"id":9792,"imdbid":"0241393","rating":0,"year":1891,"title":"Duncan and Another, Blacksmith Shop"},{"rating":0,"id":9793,"imdbid":"0241392","title":"Duncan Smoking","year":1891},{"title":"Duncan or Devonald with Muslin Cloud","year":1891,"rating":0,"id":9794,"imdbid":"0241394"},{"rating":0,"imdbid":"0241735","id":9795,"title":"Monkey and Another, Boxing","year":1891},{"id":9800,"imdbid":"3201916","rating":0,"year":1891,"title":"Je vous aime"},{"year":1891,"title":"La vague","id":9802,"imdbid":"3508566","rating":0},{"rating":0,"id":9943,"imdbid":"5447082","title":"Two Fencers","year":1891},{"title":"Pauvre Pierrot","year":1892,"rating":0,"imdbid":"0000003","id":5433},{"id":9631,"imdbid":"0000004","rating":0,"year":1892,"title":"Un bon bock"},{"rating":0,"imdbid":"0000002","id":9632,"title":"Le clown et ses chiens","year":1892},{"year":1892,"title":"Fencing","id":9951,"imdbid":"0241446","rating":0},{"title":"Le prince de Galles","year":1892,"rating":0,"imdbid":"0234520","id":9952},{"rating":0,"imdbid":"0242148","id":9948,"title":"Wrestling","year":1892},{"rating":0,"imdbid":"0241266","id":9986,"title":"Boxing","year":1892},{"id":9583,"imdbid":"0000005","rating":0,"year":1893,"title":"Blacksmith Scene"},{"year":1894,"title":"Annabelle Butterfly Dance","imdbid":"0229217","id":9636,"rating":0},{"year":1894,"title":"Edison Kinetoscope Records: Annie Oakley","imdbid":"8419312","id":964 ...
# Données enregistrées dans 'gitignore\dataforgood_bechdelai.json'

# %%
# Etape pour reprendre après déconnexion (pas besoin de refaire la requête API)
file = '..\gitignore\dataforgood_bechdelai.json'

# Charger les données depuis le fichier JSON
with open(file, 'r', encoding='utf-8') as f:
    data = json.load(f)

# Afficher les données JSON pour voir leur structure
display(data)

# Transformer l'objet JSON en dataframe
data = pd.json_normalize(data)

display(data)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\g'
# <>:2: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\jpvt\AppData\Local\Temp\ipykernel_8840\2233501114.py:2: SyntaxWarning: invalid escape sequence '\g'
#   file = '..\gitignore\dataforgood_bechdelai.json'
# [{'rating': 0,
#   'id': 9602,
#   'imdbid': '3155794',
#   'title': 'Passage de Venus',
#   'year': 1874},
#  {'rating': 0,
#   'imdbid': '14495706',
#   'id': 9804,
#   'title': 'La Rosace Magique',
#   'year': 1877},
#  {'rating': 0,
#   'id': 9603,
#   'imdbid': '2221420',
#   'title': 'Sallie Gardner at a Gallop',
#   'year': 1878},
#  {'year': 1878,
#   'title': 'Le singe musicien',
#   'imdbid': '12592084',
#   'id': 9806,
#   'rating': 0},
#  {'year': 1881,
#   'title': 'Athlete Swinging a Pick',
#   'id': 9816,
#   'imdbid': '7816420',
#   'rating': 0},
#  {'rating': 0,
#   'id': 9831,
#   'imdbid': '5459794',
#   'title': 'Buffalo Running',
#   'year': 1883},
#  {'rating': 0,
#   'imdbid': '8588366',
#   'id': 9832,
#   'title': 'L&#39;homme machine',
#   'year': 1885},
#  {'title': 'Man Walking Around the Corner',
#   'year': 1887,
#   'rating': 0,
#   'imdbid': '2075247',
#   'id': 9614},
#  {'title': 'Cockatoo Flying',
#   'year': 1887,
#   'rating': 0,
#   'imdbid': '8133192',
#   'id': 9836},
#  {'rating': 0,
#   'id': 9837,
#   'imdbid': '7411790',
#   'title': 'Child Carrying Flowers to Woman',
#   'year': 1887},
#  {'title': 'Jumping Over a Man&#39;s Back-Leapfrog',
#   'year': 1887,
#   'rating': 0,
#   'id': 9838,
#   'imdbid': '7541160'},
#  {'title': 'Man Riding Jumping Horse',
#   'year': 1887,
#   'rating': 0,
#   'imdbid': '7754902',
#   'id': 9841},
#  {'imdbid': '8361552',
#   'id': 9902,
#   'rating': 0,
#   'year': 1887,
#   'title': 'Baboon Climbing a Pole'},
#  {'id': 8040,
#   'imdbid': '0392728',
#   'rating': 0,
#   'year': 1888,
#   'title': 'Roundhay Garden Scene'},
#  {'year': 1888,
#   'title': 'Accordion Player',
#   'imdbid': '1758563',
#   'id': 9615,
#   'rating': 0},
#  {'rating': 0,
#   'imdbid': '0343112',
#   'id': 9616,
#   'title': 'Traffic Crossing Leeds Bridge',
#   'year': 1888},
#  {'title': 'Pferd und Reiter Springen uber ein Hindernis',
#   'year': 1888,
#   'rating': 0,
#   'imdbid': '3274100',
#   'id': 9675},
#  {'title': 'Brighton Street Scene',
#   'year': 1888,
#   'rating': 0,
#   'imdbid': '2116853',
#   'id': 9947},
#  {'rating': 0,
#   'id': 9619,
#   'imdbid': '0466876',
#   'title': 'Leisurely Pedestrians, Open Topped Buses and Hansom Cabs with Trotting Horses',
#   'year': 1889},
#  {'title': 'Hyde Park Corner',
#   'year': 1889,
#   'rating': 0,
#   'id': 9945,
#   'imdbid': '2116898'},
#  {'year': 1890,
#   'title': 'Monkeyshines, No. 1',
#   'imdbid': '0361921',
#   'id': 9617,
#   'rating': 0},
#  {'year': 1890,
#   'title': 'Monkeyshines, No. 2',
#   'imdbid': '0416046',
#   'id': 9618,
#   'rating': 0},
#  {'rating': 0,
#   'imdbid': '1202028',
#   'id': 9621,
#   'title': 'London&#39;s Trafalgar Square',
#   'year': 1890},
#  {'year': 1890,
#   'title': 'Monkeyshines, No. 3',
#   'imdbid': '0416047',
#   'id': 9678,
#   'rating': 0},
#  {'year': 1890,
#   'title': 'Mosquinha',
#   'id': 9946,
#   'imdbid': '5285442',
#   'rating': 0},
#  {'title': 'Traffic in King&#39;s Road, Chelsea',
#   'year': 1890,
#   'rating': 0,
#   'imdbid': '2116968',
#   'id': 9944},
#  {'title': 'Dickson Greeting',
#   'year': 1891,
#   'rating': 0,
#   'id': 9626,
#   'imdbid': '0241373'},
#  {'id': 9628,
#   'imdbid': '0241715',
#   'rating': 0,
#   'year': 1891,
#   'title': 'Men Boxing'},
#  {'imdbid': '0241763',
#   'id': 9629,
#   'rating': 0,
#   'year': 1891,
#   'title': 'Newark Athlete'},
#  {'id': 9792,
#   'imdbid': '0241393',
#   'rating': 0,
#   'year': 1891,
#   'title': 'Duncan and Another, Blacksmith Shop'},
#  {'rating': 0,
#   'id': 9793,
#   'imdbid': '0241392',
#   'title': 'Duncan Smoking',
#   'year': 1891},
#  {'title': 'Duncan or Devonald with Muslin Cloud',
#   'year': 1891,
#   'rating': 0,
#   'id': 9794,
#   'imdbid': '0241394'},
#  {'rating': 0,
#   'imdbid': '0241735',
#   'id': 9795,
#   'title': 'Monkey and Another, Boxing',
#   'year': 1891},
#  {'id': 9800,
#   'imdbid': '3201916',
#   'rating': 0,
#   'year': 1891,
#   'title': 'Je vous aime'},
#  {'year': 1891,
#   'title': 'La vague',
#   'id': 9802,
#   'imdbid': '3508566',
#   'rating': 0},
#  {'rating': 0,
#   'id': 9943,
#   'imdbid': '5447082',
#   'title': 'Two Fencers',
#   'year': 1891},
#  {'title': 'Pauvre Pierrot',
#   'year': 1892,
#   'rating': 0,
#   'imdbid': '0000003',
#   'id': 5433},
#  {'id': 9631,
#   'imdbid': '0000004',
#   'rating': 0,
#   'year': 1892,
#   'title': 'Un bon bock'},
#  {'rating': 0,
#   'imdbid': '0000002',
#   'id': 9632,
#   'title': 'Le clown et ses chiens',
#   'year': 1892},
#  {'year': 1892,
#   'title': 'Fencing',
#   'id': 9951,
#   'imdbid': '0241446',
#   'rating': 0},
#  {'title': 'Le prince de Galles',
#   'year': 1892,
#   'rating': 0,
#   'imdbid': '0234520',
#   'id': 9952},
#  {'rating': 0,
#   'imdbid': '0242148',
#   'id': 9948,
#   'title': 'Wrestling',
#   'year': 1892},
#  {'rating': 0,
#   'imdbid': '0241266',
#   'id': 9986,
#   'title': 'Boxing',
#   'year': 1892},
#  {'id': 9583,
#   'imdbid': '0000005',
#   'rating': 0,
#   'year': 1893,
#   'title': 'Blacksmith Scene'},
#  {'year': 1894,
#   'title': 'Annabelle Butterfly Dance',
#   'imdbid': '0229217',
#   'id': 9636,
#   'rating': 0},
#  {'year': 1894,
#   'title': 'Edison Kinetoscope Records: Annie Oakley',
#   'imdbid': '8419312',
#   'id': 9642,
#   'rating': 0},
#  {'title': 'Autour d&#39;une cabine',
#   'year': 1894,
#   'rating': 0,
#   'imdbid': '0000015',
#   'id': 9646},
#  {'year': 1894,
#   'title': 'Barbershop, The',
#   'imdbid': '0229235',
#   'id': 9648,
#   'rating': 0},
#  {'year': 1894,
#   'title': 'Bucking Broncho',
#   'imdbid': '0309396',
#   'id': 9649,
#   'rating': 0},
#  {'title': 'Buffalo Dance',
#   'year': 1894,
#   'rating': 0,
#   'id': 9650,
#   'imdbid': '0309402'},
#  {'id': 9652,
#   'imdbid': '0000008',
#   'rating': 0,
#   'year': 1894,
#   'title': 'Edison Kinetoscopic Record of a Sneeze'},
#  {'title': 'Dickson Experimental Sound Film',
#   'year': 1894,
#   'rating': 0,
#   'id': 9654,
#   'imdbid': '0177707'},
#  {'title': 'Chinese Opium Den',
#   'year': 1894,
#   'rating': 0,
#   'imdbid': '0000006',
#   'id': 9655},
#  {'imdbid': '0000007',
#   'id': 9656,
#   'rating': 0,
#   'year': 1894,
#   'title': 'Corbett and Courtney Before the Kinetograph'},
#  {'title': 'Falling Cat',
#   'year': 1894,
#   'rating': 0,
#   'imdbid': '2049440',
#   'id': 9662},
#  {'year': 1894,
#   'title': 'Glenroy Bros., No. 2',
#   'imdbid': '0312728',
#   'id': 9663,
#   'rating': 0},
#  {'id': 9664,
#   'imdbid': '0256782',
#   'rating': 0,
#   'year': 1894,
#   'title': 'Glenroy Brothers'},
#  {'id': 9668,
#   'imdbid': '0203646',
#   'rating': 0,
#   'year': 1894,
#   'title': 'Leonard-Cushing Fight'},
#  {'rating': 0,
#   'imdbid': '0277115',
#   'id': 9671,
#   'title': 'Luis Martinetti, Contortionist',
#   'year': 1894},
#  {'imdbid': '2161519',
#   'id': 9673,
#   'rating': 0,
#   'year': 1894,
#   'title': 'Sandow No. 2'},
#  {'rating': 0,
#   'imdbid': '2161521',
#   'id': 9674,
#   'title': 'Sandow No. 3',
#   'year': 1894},
#  {'id': 9681,
#   'imdbid': '0413219',
#   'rating': 0,
#   'year': 1894,
#   'title': 'Reve au coin du feu'},
#  {'rating': 0,
#   'imdbid': '0000009',
#   'id': 9779,
#   'title': 'Miss Jerry',
#   'year': 1894},
#  {'title': 'Tables Turned on the Gardener',
#   'year': 1895,
#   'rating': 0,
#   'id': 5444,
#   'imdbid': '0000014'},
#  {'id': 6200,
#   'imdbid': '0132134',
#   'rating': 0,
#   'year': 1895,
#   'title': 'Execution of Mary, Queen of Scots, The'},
#  {'rating': 1,
#   'imdbid': '0000011',
#   'id': 9679,
#   'title': 'Akrobatisches Potpourri',
#   'year': 1895},
#  {'title': 'Annabelle Serpentine Dance',
#   'year': 1895,
#   'rating': 0,
#   'id': 9683,
#   'imdbid': '0154152'},
#  {'rating': 0,
#   'imdbid': '0000017',
#   'id': 9714,
#   'title': 'Italienischer Bauerntanz',
#   'year': 1895},
#  {'rating': 1,
#   'id': 9715,
#   'imdbid': '0000029',
#   'title': 'Baby&#39;s Dinner',
#   'year': 1895},
#  {'year': 1895,
#   'title': 'Billy Edwards and the Unknown',
#   'id': 9766,
#   'imdbid': '0477266',
#   'rating': 0},
#  {'imdbid': '0000022',
#   'id': 9767,
#   'rating': 0,
#   'year': 1895,
#   'title': 'Blacksmith Scene'},
#  {'rating': 0,
#   'imdbid': '0000016',
#   'id': 9787,
#   'title': 'Barque sortant du port',
#   'year': 1895},
#  {'title': 'House of the Devil, The',
#   'year': 1896,
#   'rating': 0,
#   'imdbid': '0000091',
#   'id': 4982},
#  {'title': 'Une nuit terrible',
#   'year': 1896,
#   'rating': 0,
#   'id': 5406,
#   'imdbid': '0000131'},
#  {'title': 'La fee aux choux',
#   'year': 1896,
#   'rating': 0,
#   'id': 5445,
#   'imdbid': '0223341'},
#  {'title': 'Arrival of a Train, The',
#   'year': 1896,
#   'rating': 0,
#   'imdbid': '0000012',
#   'id': 6199},
#  {'title': 'Sandow',
#   'year': 1896,
#   'rating': 0,
#   'imdbid': '1428455',
#   'id': 9672},
#  {'year': 1896,
#   'title': 'Alger: rue Bab-Azoun',
#   'id': 9949,
#   'imdbid': '1672718',
#   'rating': 0},
#  {'imdbid': '1736599',
#   'id': 9950,
#   'rating': 0,
#   'year': 1896,
#   'title': 'Lassage des boeufs pour le labour'},
#  {'year': 1896,
#   'title': 'Lancement d&#39;un navire',
#   'imdbid': '0222137',
#   'id': 9901,
#   'rating': 0},
#  {'title': 'Bataille de neige',
#   'year': 1897,
#   'rating': 0,
#   'imdbid': '0000041',
#   'id': 9328},
#  {'year': 1898,
#   'title': 'Four Heads Are Better Than One',
#   'imdbid': '0135696',
#   'id': 4978,
#   'rating': 0},
#  {'title': 'Astronomer&#39;s Dream; or, The Man in the Moon, The',
#   'year': 1898,
#   'rating': 0,
#   'id': 5410,
#   'imdbid': '0000211'},
#  {'year': 1898,
#   'title': 'Temptation of St. Anthony, The',
#   'id': 5411,
#   'imdbid': '0224240',
#   'rating': 0},
#  {'imdbid': '0000246',
#   'id': 4994,
#   'rating': 0,
#   'year': 1899,
#   'title': 'A Turn of the Century Illusionist'},
#  {'year': 1899,
#   'title': 'Cinderella',
#   'imdbid': '0000230',
#   'id': 5914,
#   'rating': 3},
#  {'title': 'Sherlock Holmes Baffled',
#   'year': 1900,
#   'rating': 0,
#   'imdbid': '0291476',
#   'id': 1594},
#  {'rating': 0,
#   'imdbid': '0000300',
#   'id': 4271,
#   'title': 'Enchanted Drawing, The',
#   'year': 1900},
#  {'id': 4343,
#   'imdbid': '0000304',
#   'rating': 0,
#   'year': 1900,
#   'title': 'Grandma&#39;s Reading Glass'},
#  {'title': 'As Seen Through A Telescope (a.k.a The Professor and His Field Glass)',
#   'year': 1900,
#   'rating': 0,
#   'imdbid': '0000272',
#   'id': 4344},
#  {'year': 1900,
#   'title': 'Explosion of a Motor Car (a.k.a The Dlights of Automobiling)',
#   'id': 4345,
#   'imdbid': '0257654',
#   'rating': 0},
#  {'title': 'Hamlet ( Le Duel d&#39;Hamlet)',
#   'year': 1900,
#   'rating': 0,
#   'id': 4346,
#   'imdbid': '0000306'},
#  {'year': 1900,
#   'title': 'One-Man Band, The',
#   'imdbid': '0135453',
#   'id': 4993,
#   'rating': 0},
#  {'id': 5069,
#   'imdbid': '0377995',
#   'rating': 0,
#   'year': 1900,
#   'title': 'Grandma Threading Her Needle'},
#  {'year': 1900,
#   'title': 'Searching Ruins on Broadway, Galveston, for Dead Bodies',
#   'id': 5072,
#   'imdbid': '0230746',
#   'rating': 0},
#  {'year': 1900,
#   'title': 'Let Me Dream Again',
#   'id': 5438,
#   'imdbid': '0000313',
#   'rating': 0},
#  {'imdbid': '0227438',
#   'id': 5446,
#   'rating': 0,
#   'year': 1900,
#   'title': 'Doctor and the Monkey, The'},
#  {'year': 1901,
#   'title': 'L&#39;homme a la tete en caoutchouc',
#   'id': 4995,
#   'imdbid': '0000359',
#   'rating': 0},
#  {'rating': 0,
#   'id': 5437,
#   'imdbid': '0258104',
#   'title': 'Reve et realite',
#   'year': 1901},
#  {'year': 1901,
#   'title': 'Bluebeard',
#   'id': 5500,
#   'imdbid': '0131934',
#   'rating': 0},
#  {'year': 1902,
#   'title': 'Le voyage dans la lune',
#   'imdbid': '0000417',
#   'id': 1252,
#   'rating': 0},
#  {'rating': 0,
#   'id': 5431,
#   'imdbid': '0229024',
#   'title': 'Gulliver&#39;s Travels',
#   'year': 1902},
#  {'imdbid': '0367177',
#   'id': 5432,
#   'rating': 0,
#   'year': 1902,
#   'title': 'Twentieth Century Tramp; or, Happy Hooligan and His Airship, The'},
#  {'year': 1902,
#   'title': 'Mephistopheles&#39; School of Magic',
#   'id': 5443,
#   'imdbid': '0000413',
#   'rating': 0},
#  {'year': 1903,
#   'title': 'Great Train Robbery, The',
#   'imdbid': '0000439',
#   'id': 1319,
#   'rating': 0},
#  {'rating': 0,
#   'imdbid': '0135180',
#   'id': 5002,
#   'title': 'Infernal Boiling Pot, The',
#   'year': 1903},
#  {'title': 'Music Lover, The',
#   'year': 1903,
#   'rating': 0,
#   'imdbid': '0000455',
#   'id': 5063},
#  {'rating': 0,
#   'id': 5064,
#   'imdbid': '0223755',
#   'title': 'Monster, The',
#   'year': 1903},
#  {'year': 1903,
#   'title': 'Enchanted Well, The',
#   'imdbid': '0189498',
#   'id': 5683,
#   'rating': 0},
#  {'imdbid': '0215664',
#   'id': 5224,
#   'rating': 0,
#   'year': 1904,
#   'title': 'Cook in Trouble, The'},
#  {'rating': 0,
#   'imdbid': '0135179',
#   'id': 5404,
#   'title': 'Living Playing Cards, The',
#   'year': 1904},
#  {'year': 1904,
#   'title': 'Untamable Whiskers, The',
#   'imdbid': '0135631',
#   'id': 5601,
#   'rating': 0},
#  {'rating': 0,
#   'imdbid': '0000499',
#   'id': 6135,
#   'title': 'Le voyage a travers l&#39;impossible',
#   'year': 1904},
#  {'rating': 0,
#   'id': 5003,
#   'imdbid': '0135690',
#   'title': 'Scheming Gambler&#39;s Paradise, The',
#   'year': 1905},
#  {'year': 1905,
#   'title': 'Black Imp, The',
#   'id': 5602,
#   'imdbid': '0215575',
#   'rating': 0},
#  {'id': 1349,
#   'imdbid': '0000574',
#   'rating': 1,
#   'year': 1906,
#   'title': 'Story of the Kelly Gang, The'},
#  {'title': 'Mysterious Retort, The',
#   'year': 1906,
#   'rating': 0,
#   'imdbid': '0216016',
#   'id': 5024},
#  {'rating': 0,
#   'imdbid': '0000554',
#   'id': 5435,
#   'title': 'Humorous Phases of Funny Faces',
#   'year': 1906},
#  {'rating': 0,
#   'imdbid': '0135122',
#   'id': 5603,
#   'title': 'Hilarious Posters, The',
#   'year': 1906},
#  {'year': 1906,
#   'title': '400 Tricks of the Devil, The',
#   'imdbid': '0000567',
#   'id': 5684,
#   'rating': 0},
#  {'year': 1906,
#   'title': 'A Funny Shave',
#   'id': 6206,
#   'imdbid': '0449172',
#   'rating': 0},
#  {'id': 7215,
#   'imdbid': '1260944',
#   'rating': 0,
#   'year': 1906,
#   'title': 'Consequence of Feminism, The'},
#  {'imdbid': '0215737',
#   'id': 5223,
#   'rating': 0,
#   'year': 1907,
#   'title': 'Eclipse: Courtship of the Sun and Moon, The'},
#  {'imdbid': '0215817',
#   'id': 5615,
#   'rating': 0,
#   'year': 1907,
#   'title': 'Good Glue Sticks'},
#  {'rating': 0,
#   'imdbid': '1802750',
#   'id': 6231,
#   'title': 'Unusual Cooking',
#   'year': 1908},
#  {'id': 4409,
#   'imdbid': '0001009',
#   'rating': 2,
#   'year': 1909,
#   'title': 'Princess Nicotine; or, The Smoke Fairy'},
#  {'rating': 0,
#   'imdbid': '0127948',
#   'id': 5635,
#   'title': 'Devilish Tenant, The',
#   'year': 1909},
#  {'title': 'Le barometre de la fidelite',
#   'year': 1909,
#   'rating': 1,
#   'id': 6211,
#   'imdbid': '0277596'},
#  {'id': 1464,
#   'imdbid': '0232821',
#   'rating': 3,
#   'year': 1910,
#   'title': 'Tilly the Tomboy Visits the Poor'},
#  {'imdbid': '0486978',
#   'id': 4983,
#   'rating': 0,
#   'year': 1910,
#   'title': 'Mobilier fidele'},
#  {'year': 1910,
#   'title': 'A Trip to Mars',
#   'id': 5685,
#   'imdbid': '1515725',
#   'rating': 0},
#  {'title': 'Cleopatra',
#   'year': 1912,
#   'rating': 2,
#   'imdbid': '0002101',
#   'id': 2003},
#  {'title': 'Invaders, The',
#   'year': 1912,
#   'rating': 0,
#   'id': 2005,
#   'imdbid': '0002281'},
#  {'year': 1912,
#   'title': 'Max and the Donkey',
#   'id': 5357,
#   'imdbid': '0277865',
#   'rating': 0},
#  {'title': 'Voyage of the Bourrichon Family, The',
#   'year': 1913,
#   'rating': 0,
#   'imdbid': '0003512',
#   'id': 5364},
#  {'title': 'Suspense',
#   'year': 1913,
#   'rating': 0,
#   'imdbid': '0003424',
#   'id': 5915},
#  {'title': 'A Florida Enchantment',
#   'year': 1914,
#   'rating': 2,
#   'imdbid': '0003973',
#   'id': 4457},
#  {'rating': 2,
#   'id': 1258,
#   'imdbid': '0004972',
#   'title': 'Birth of a Nation, The',
#   'year': 1915},
#  {'id': 11370,
#   'imdbid': '0004134',
#   'rating': 0,
#   'year': 1915,
#   'title': 'Hypocrites'},
#  {'title': 'Gretchen the Greenhorn',
#   'year': 1916,
#   'rating': 3,
#   'imdbid': '0006745',
#   'id': 2008},
#  {'title': 'Lady Windermere&#39;s Fan',
#   'year': 1916,
#   'rating': 3,
#   'imdbid': '0279914',
#   'id': 2014},
#  {'year': 1916,
#   'title': 'Vagabond, The',
#   'id': 5368,
#   'imdbid': '0007507',
#   'rating': 0},
#  {'imdbid': '0006864',
#   'id': 5944,
#   'rating': 0,
#   'year': 1916,
#   'title': 'Intolerance: Love&#39;s Struggle Throughout the Ages'},
#  {'imdbid': '0007361',
#   'id': 7004,
#   'rating': 3,
#   'year': 1916,
#   'title': 'Snow White'},
#  {'imdbid': '0008652',
#   'id': 1981,
#   'rating': 3,
#   'year': 1917,
#   'title': 'A Tale of Two Cities'},
#  {'year': 1917,
#   'title': 'Rebecca of Sunnybrook Farm',
#   'imdbid': '0008499',
#   'id': 1993,
#   'rating': 3},
#  {'rating': 3,
#   'id': 1994,
#   'imdbid': '0008443',
#   'title': 'Poor Little Rich Girl, The',
#   'year': 1917},
#  {'year': 1917,
#   'title': 'A Romance of the Redwoods',
#   'id': 2015,
#   'imdbid': '0008519',
#   'rating': 0},
#  {'title': 'Raffles, the Amateur Cracksman',
#   'year': 1917,
#   'rating': 2,
#   'imdbid': '0008489',
#   'id': 2019},
#  {'title': 'Tarzan of the Apes',
#   'year': 1918,
#   'rating': 3,
#   'imdbid': '0009682',
#   'id': 1996},
#  {'imdbid': '0009652',
#   'id': 2007,
#   'rating': 3,
#   'year': 1918,
#   'title': 'Stella Maris'},
#  {'title': 'Are Crooks Dishonest?',
#   'year': 1918,
#   'rating': 0,
#   'imdbid': '0008844',
#   'id': 5441},
#  {'year': 1918,
#   'title': 'Ich mochte kein Mann sein',
#   'id': 7108,
#   'imdbid': '0010281',
#   'rating': 3},
#  {'imdbid': '0010879',
#   'id': 2018,
#   'rating': 3,
#   'year': 1919,
#   'title': 'When the Clouds Roll by'},
#  {'year': 1919,
#   'title': 'Broken Blossoms or The Yellow Man and the Girl',
#   'id': 2588,
#   'imdbid': '0009968',
#   'rating': 0},
#  {'title': 'Cabinet of Dr. Caligari, The',
#   'year': 1920,
#   'rating': 0,
#   'id': 1306,
#   'imdbid': '0010323'},
#  {'title': 'Pollyanna',
#   'year': 1920,
#   'rating': 3,
#   'imdbid': '0011588',
#   'id': 1991},
#  {'rating': 3,
#   'id': 5948,
#   'imdbid': '0011870',
#   'title': 'Within Our Gates',
#   'year': 1920},
#  {'id': 1263,
#   'imdbid': '0012532',
#   'rating': 3,
#   'year': 1921,
#   'title': 'Orphans of the Storm'},
#  {'rating': 0,
#   'id': 3945,
#   'imdbid': '0012349',
#   'title': 'Kid, The',
#   'year': 1921},
#  {'year': 1921,
#   'title': 'Blot, The',
#   'imdbid': '0011979',
#   'id': 4204,
#   'rating': 3},
#  {'id': 5898,
#   'imdbid': '0012364',
#   'rating': 2,
#   'year': 1921,
#   'title': 'K&ouml;rkarlen (The Phantom Carriage)'},
#  {'rating': 2,
#   'id': 1307,
#   'imdbid': '0013442',
#   'title': 'Nosferatu, eine Symphonie des Grauens',
#   'year': 1922},
#  {'id': 1631,
#   'imdbid': '0013496',
#   'rating': 2,
#   'year': 1922,
#   'title': 'Phantom, The'},
#  {'year': 1922,
#   'title': 'Nathan der Weise',
#   'imdbid': '0013428',
#   'id': 1778,
#   'rating': 2},
#  {'rating': 1,
#   'id': 2001,
#   'imdbid': '0013367',
#   'title': 'Man from Beyond, The',
#   'year': 1922},
#  {'rating': 3,
#   'imdbid': '0013257',
#   'id': 3800,
#   'title': 'H&auml;xan: Witchcraft Through the Ages',
#   'year': 1922},
#  {'id': 5361,
#   'imdbid': '0012543',
#   'rating': 0,
#   'year': 1922,
#   'title': 'Paleface, The'},
#  {'rating': 1,
#   'imdbid': '0013427',
#   'id': 5901,
#   'title': 'Nanook of the North',
#   'year': 1922},
#  {'rating': 3,
#   'imdbid': '0013140',
#   'id': 5958,
#   'title': 'Foolish Wives',
#   'year': 1922},
#  {'year': 1922,
#   'title': 'Dr. Mabuse, der Spieler - Ein Bild der Zeit',
#   'imdbid': '0013086',
#   'id': 5967,
#   'rating': 3},
#  {'year': 1923,
#   'title': 'Safety Last!',
#   'id': 1961,
#   'imdbid': '0014429',
#   'rating': 0},
#  {'imdbid': '0014611',
#   'id': 1967,
#   'rating': 0,
#   'year': 1923,
#   'title': 'Why Worry?'},
#  {'imdbid': '0014469',
#   'id': 1998,
#   'rating': 2,
#   'year': 1923,
#   'title': 'Silent Command, The'},
#  {'rating': 3,
#   'imdbid': '0013626',
#   'id': 5888,
#   'title': 'La souriante Madame Beudet',
#   'year': 1923},
#  {'title': 'Our Hospitality',
#   'year': 1923,
#   'rating': 0,
#   'imdbid': '0014341',
#   'id': 5949},
#  {'year': 1923,
#   'title': 'A Woman of Paris',
#   'imdbid': '0014624',
#   'id': 8947,
#   'rating': 2},
#  {'year': 1924,
#   'title': 'Die Nibelungen',
#   'id': 1337,
#   'imdbid': '0015175',
#   'rating': 2},
#  {'year': 1924,
#   'title': 'Kriemhild&#39;s Revenge',
#   'id': 1338,
#   'imdbid': '0015174',
#   'rating': 2},
#  {'title': 'Thief of Bagdad, The',
#   'year': 1924,
#   'rating': 0,
#   'id': 1264,
#   'imdbid': '0015400'},
#  {'title': 'Wild Oranges',
#   'year': 1924,
#   'rating': 0,
#   'imdbid': '0015498',
#   'id': 1960},
#  {'title': 'Navigator, The',
#   'year': 1924,
#   'rating': 0,
#   'imdbid': '0015163',
#   'id': 2009},
#  {'imdbid': '0015324',
#   'id': 2011,
#   'rating': 0,
#   'year': 1924,
#   'title': 'Sherlock Jr.'},
#  {'imdbid': '0014945',
#   'id': 2016,
#   'rating': 0,
#   'year': 1924,
#   'title': 'Girl Shy'},
#  {'title': 'Manhandled',
#   'year': 1924,
#   'rating': 3,
#   'id': 2020,
#   'imdbid': '0015116'},
#  {'rating': 0,
#   'id': 2413,
#   'imdbid': '1764657',
#   'title': 'Great White Silence, The',
#   'year': 1924},
#  {'rating': 0,
#   'imdbid': '0013845',
#   'id': 6209,
#   'title': 'Help!',
#   'year': 1924},
#  {'title': 'Greed',
#   'year': 1924,
#   'rating': 3,
#   'imdbid': '0015881',
#   'id': 8458},
#  {'imdbid': '0016220',
#   'id': 1305,
#   'rating': 2,
#   'year': 1925,
#   'title': 'Phantom of the Opera, The'},
#  {'year': 1925,
#   'title': 'Battleship Potemkin',
#   'id': 1308,
#   'imdbid': '0015648',
#   'rating': 0},
#  {'rating': 0,
#   'imdbid': '0015864',
#   'id': 1309,
#   'title': 'Gold Rush, The',
#   'year': 1925},
#  {'rating': 0,
#   'id': 1978,
#   'imdbid': '0015863',
#   'title': 'Go West',
#   'year': 1925},
#  {'year': 1925,
#   'title': 'Freshman, The',
#   'id': 2012,
#   'imdbid': '0015841',
#   'rating': 0},
#  {'title': 'Seven Chances',
#   'year': 1925,
#   'rating': 0,
#   'imdbid': '0016332',
#   'id': 3077},
#  {'year': 1925,
#   'title': 'Lost World, The',
#   'id': 5514,
#   'imdbid': '0016039',
#   'rating': 2},
#  {'title': 'Big Parade, The',
#   'year': 1925,
#   'rating': 2,
#   'imdbid': '0015624',
#   'id': 5962},
#  {'title': 'Stachka',
#   'year': 1925,
#   'rating': 0,
#   'id': 5991,
#   'imdbid': '0015361'},
#  {'rating': 1,
#   'id': 1334,
#   'imdbid': '0017449',
#   'title': 'Temptress, The',
#   'year': 1926},
#  {'imdbid': '0016884',
#   'id': 1260,
#   'rating': 1,
#   'year': 1926,
#   'title': 'Flesh and the Devil'},
#  {'imdbid': '0017925',
#   'id': 1310,
#   'rating': 0,
#   'year': 1926,
#   'title': 'General, The'},
#  {'rating': 0,
#   'imdbid': '0016895',
#   'id': 1966,
#   'title': 'For Heaven&#39;s Sake',
#   'year': 1926},
#  {'year': 1926,
#   'title': 'So&#39;s Your Old Man',
#   'id': 3217,
#   'imdbid': '0017410',
#   'rating': 3},
#  {'rating': 1,
#   'id': 5974,
#   'imdbid': '0015532',
#   'title': 'Die Abenteuer des Prinzen Achmed',
#   'year': 1926},
#  {'year': 1927, 'title': 'It', 'imdbid': '0018033', 'id': 1227, 'rating': 3},
#  {'title': 'Metropolis',
#   'year': 1927,
#   'rating': 1,
#   'imdbid': '0017136',
#   'id': 1267},
#  {'year': 1927,
#   'title': 'Abel Gance&#39;s Napoleon',
#   'id': 1312,
#   'imdbid': '0018192',
#   'rating': 2},
#  {'year': 1927,
#   'title': 'Unknown, The',
#   'imdbid': '0018528',
#   'id': 1311,
#   'rating': 0},
#  {'imdbid': '0018455',
#   'id': 1632,
#   'rating': 2,
#   'year': 1927,
#   'title': 'Sunrise: A Song of Two Humans'},
#  {'year': 1927,
#   'title': 'Kid Brother, The',
#   'imdbid': '0018051',
#   'id': 1964,
#   'rating': 0},
#  {'imdbid': '0018199',
#   'id': 1982,
#   'rating': 0,
#   'year': 1927,
#   'title': 'Nevada'},
#  {'year': 1927,
#   'title': 'My Best Girl',
#   'id': 2010,
#   'imdbid': '0018183',
#   'rating': 3},
#  {'id': 3118,
#   'imdbid': '0018578',
#   'rating': 1,
#   'year': 1927,
#   'title': 'Wings'},
#  {'title': 'Jazz Singer, The',
#   'year': 1927,
#   'rating': 1,
#   'imdbid': '0018037',
#   'id': 5975},
#  {'title': 'Downhill [When Boys Leave Home]',
#   'year': 1927,
#   'rating': 1,
#   'imdbid': '0017825',
#   'id': 7324},
#  {'imdbid': '0017739',
#   'id': 11142,
#   'rating': 3,
#   'year': 1927,
#   'title': 'Cat and the Canary, The'},
#  {'year': 1928,
#   'title': 'Passion of Joan of Arc, The',
#   'imdbid': '0019254',
#   'id': 1314,
#   'rating': 0},
#  {'title': 'Speedy',
#   'year': 1928,
#   'rating': 0,
#   'id': 1963,
#   'imdbid': '0019412'},
#  {'imdbid': '0018773',
#   'id': 1968,
#   'rating': 0,
#   'year': 1928,
#   'title': 'Circus, The'},
#  {'year': 1928,
#   'title': 'Cameraman, The',
#   'id': 1970,
#   'imdbid': '0018742',
#   'rating': 0},
#  {'title': 'Steamboat Bill, Jr.',
#   'year': 1928,
#   'rating': 0,
#   'id': 1971,
#   'imdbid': '0019421'},
#  {'year': 1928,
#   'title': 'Racket, The',
#   'imdbid': '0019304',
#   'id': 1972,
#   'rating': 0},
#  {'year': 1928,
#   'title': 'Beggars of Life',
#   'id': 1977,
#   'imdbid': '0018684',
#   'rating': 0},
#  {'rating': 1,
#   'id': 1979,
#   'imdbid': '0019290',
#   'title': 'Power of the Press, The',
#   'year': 1928},
#  {'rating': 0,
#   'id': 1980,
#   'imdbid': '0018937',
#   'title': 'A Girl in Every Port',
#   'year': 1928},
#  {'year': 1928,
#   'title': 'Patsy, The',
#   'imdbid': '0019258',
#   'id': 2013,
#   'rating': 3},
#  {'title': 'While the City Sleeps',
#   'year': 1928,
#   'rating': 2,
#   'id': 2017,
#   'imdbid': '0019571'},
#  {'year': 1928,
#   'title': 'Man Who Laughs, The',
#   'id': 2021,
#   'imdbid': '0019130',
#   'rating': 2},
#  {'rating': 1,
#   'id': 5912,
#   'imdbid': '0018806',
#   'title': 'Crowd, The',
#   'year': 1928},
#  {'title': 'Docks of New York, The',
#   'year': 1928,
#   'rating': 2,
#   'imdbid': '0018839',
#   'id': 5984},
#  {'rating': 2,
#   'id': 9314,
#   'imdbid': '0019237',
#   'title': 'Our Dancing Daughters',
#   'year': 1928},
#  {'rating': 0,
#   'imdbid': '0020530',
#   'id': 1313,
#   'title': 'Un chien andalou',
#   'year': 1929},
#  {'title': 'Cocoanuts, The',
#   'year': 1929,
#   'rating': 2,
#   'id': 1953,
#   'imdbid': '0019777'},
#  {'imdbid': '0020572',
#   'id': 1962,
#   'rating': 0,
#   'year': 1929,
#   'title': 'Welcome Danger'},
#  {'rating': 3,
#   'imdbid': '0018737',
#   'id': 2324,
#   'title': 'Pandora&#39;s Box (Die B&uuml;chse der Pandora)',
#   'year': 1929},
#  {'rating': 0,
#   'imdbid': '0019760',
#   'id': 3897,
#   'title': 'Man with a Movie Camera',
#   'year': 1929},
#  {'year': 1929,
#   'title': 'Blackmail',
#   'id': 5979,
#   'imdbid': '0019702',
#   'rating': 2},
#  {'imdbid': '0020286',
#   'id': 6046,
#   'rating': 0,
#   'year': 1929,
#   'title': 'Throw of the Dice'},
#  {'year': 1929,
#   'title': 'Juno and the Paycock [The Shame of Mary Boyle]',
#   'imdbid': '0021015',
#   'id': 7287,
#   'rating': 3},
#  {'title': 'Broadway Melody',
#   'year': 1929,
#   'rating': 3,
#   'imdbid': '0019729',
#   'id': 8464},
#  {'title': 'Blue Angel, The',
#   'year': 1930,
#   'rating': 1,
#   'imdbid': '0020697',
#   'id': 1315},
#  {'rating': 0,
#   'imdbid': '0020629',
#   'id': 1316,
#   'title': 'All Quiet on the Western Front',
#   'year': 1930},
#  {'year': 1930,
#   'title': 'Anna Christie',
#   'id': 1326,
#   'imdbid': '0020641',
#   'rating': 3},
#  {'rating': 3,
#   'id': 3713,
#   'imdbid': '0021040',
#   'title': 'Ladies of Leisure',
#   'year': 1930},
#  {'year': 1930,
#   'title': 'L&#39;Age d&#39;Or',
#   'id': 3871,
#   'imdbid': '0021577',
#   'rating': 0},
#  {'rating': 1,
#   'imdbid': '0021156',
#   'id': 3865,
#   'title': 'Morocco',
#   'year': 1930},
#  {'year': 1930,
#   'title': 'Min and Bill',
#   'imdbid': '0021148',
#   'id': 3927,
#   'rating': 3},
#  {'year': 1930,
#   'title': 'Be Yourself',
#   'imdbid': '0020670',
#   'id': 4253,
#   'rating': 2},
#  {'rating': 3,
#   'imdbid': '0020668',
#   'id': 6782,
#   'title': 'Bat Whispers, The',
#   'year': 1930},
#  {'id': 7291,
#   'imdbid': '0021165',
#   'rating': 3,
#   'year': 1930,
#   'title': 'Murder!'},
#  {'year': 1930,
#   'title': 'Animal Crackers',
#   'id': 8463,
#   'imdbid': '0020640',
#   'rating': 3},
#  {'year': 1931, 'title': 'M', 'imdbid': '0022100', 'id': 610, 'rating': 3},
#  {'rating': 3,
#   'imdbid': '0022183',
#   'id': 628,
#   'title': 'M&auml;dchen in Uniform',
#   'year': 1931},
#  {'title': 'Night Nurse',
#   'year': 1931,
#   'rating': 3,
#   'imdbid': '0022208',
#   'id': 636},
#  {'year': 1931,
#   'title': 'Frankenstein',
#   'id': 1317,
#   'imdbid': '0021884',
#   'rating': 1},
#  {'rating': 3,
#   'imdbid': '0020642',
#   'id': 1327,
#   'title': 'Anna Christie',
#   'year': 1931},
#  {'year': 1931,
#   'title': 'Mata Hari',
#   'id': 1333,
#   'imdbid': '0023196',
#   'rating': 3},
#  {'year': 1931,
#   'title': 'Tabu: A Story of the South Seas',
#   'id': 1633,
#   'imdbid': '0022458',
#   'rating': 0},
#  {'title': 'Indiscreet',
#   'year': 1931,
#   'rating': 3,
#   'imdbid': '0022000',
#   'id': 1828},
#  {'id': 1956,
#   'imdbid': '0022054',
#   'rating': 0,
#   'year': 1931,
#   'title': 'Last Flight, The'},
#  {'rating': 0,
#   'imdbid': '0022251',
#   'id': 1974,
#   'title': 'Pardon Us',
#   'year': 1931},
#  {'id': 1985,
#   'imdbid': '0021814',
#   'rating': 2,
#   'year': 1931,
#   'title': 'Dracula'},
#  {'year': 1931,
#   'title': 'Monkey Business',
#   'id': 2384,
#   'imdbid': '0022158',
#   'rating': 1},
#  {'year': 1931,
#   'title': 'City Lights',
#   'imdbid': '0021749',
#   'id': 2705,
#   'rating': 3},
#  {'year': 1931,
#   'title': 'Smiling Lieutenant, The',
#   'imdbid': '0022074',
#   'id': 4243,
#   'rating': 2},
#  {'year': 1931,
#   'title': 'Cheat, The',
#   'imdbid': '0021735',
#   'id': 5741,
#   'rating': 3},
#  {'year': 1931,
#   'title': 'Public Enemy, The',
#   'id': 5934,
#   'imdbid': '0022286',
#   'rating': 3},
#  {'year': 1931,
#   'title': 'La Chienne',
#   'id': 6030,
#   'imdbid': '0021739',
#   'rating': 3},
#  {'imdbid': '0022599',
#   'id': 6031,
#   'rating': 1,
#   'year': 1931,
#   'title': 'A Nous la Liberte'},
#  {'imdbid': '0021079',
#   'id': 6043,
#   'rating': 1,
#   'year': 1931,
#   'title': 'Little Caesar'},
#  {'year': 1931,
#   'title': 'Skin Game, The',
#   'id': 7294,
#   'imdbid': '0022395',
#   'rating': 3},
#  {'title': 'Rich and Strange [East of Shanghai]',
#   'year': 1931,
#   'rating': 2,
#   'imdbid': '0023395',
#   'id': 7296},
#  {'rating': 3,
#   'imdbid': '0021815',
#   'id': 8213,
#   'title': 'Dracula',
#   'year': 1931},
#  {'rating': 3,
#   'imdbid': '0021746',
#   'id': 8467,
#   'title': 'Cimarron',
#   'year': 1931},
#  {'imdbid': '0021985',
#   'id': 8557,
#   'rating': 1,
#   'year': 1931,
#   'title': 'Hyppolit a lakaj'},
#  {'year': 1931,
#   'title': 'Skippy',
#   'id': 9095,
#   'imdbid': '0022397',
#   'rating': 3},
#  {'rating': 1,
#   'id': 9110,
#   'imdbid': '0021730',
#   'title': 'Champ, The',
#   'year': 1931},
#  {'title': 'I Am a Fugitive from a Chain Gang',
#   'year': 1932,
#   'rating': 1,
#   'imdbid': '0023042',
#   'id': 1318},
#  {'year': 1932,
#   'title': 'Grand Hotel',
#   'imdbid': '0022958',
#   'id': 1328,
#   'rating': 3},
#  {'title': 'Age of Consent, The',
#   'year': 1932,
#   'rating': 2,
#   'imdbid': '0022614',
#   'id': 1983},
#  {'year': 1932,
#   'title': 'Horse Feathers',
#   'imdbid': '0023027',
#   'id': 2383,
#   'rating': 1},
#  {'year': 1932,
#   'title': 'White Zombie',
#   'id': 2550,
#   'imdbid': '0023694',
#   'rating': 0},
#  {'rating': 1,
#   'imdbid': '0022718',
#   'id': 2767,
#   'title': 'Boudu Saved from Drowning',
#   'year': 1932},
#  {'year': 1932,
#   'title': 'I Was Born, But...',
#   'id': 3530,
#   'imdbid': '0023634',
#   'rating': 1},
#  {'id': 3658,
#   'imdbid': '0023238',
#   'rating': 0,
#   'year': 1932,
#   'title': 'Most Dangerous Game, The'},
#  {'rating': 2,
#   'imdbid': '0022913',
#   'id': 3659,
#   'title': 'Freaks',
#   'year': 1932},
#  {'id': 3844,
#   'imdbid': '0024188',
#   'rating': 1,
#   'year': 1932,
#   'title': 'Island of Lost Souls'},
#  {'title': 'Old Dark House, The',
#   'year': 1932,
#   'rating': 3,
#   'id': 4775,
#   'imdbid': '0023293'},
#  {'rating': 3,
#   'id': 5742,
#   'imdbid': '0023213',
#   'title': 'Merrily We Go to Hell',
#   'year': 1932},
#  {'year': 1932,
#   'title': 'Girl from Calgary, The',
#   'imdbid': '0022940',
#   'id': 5783,
#   'rating': 2},
#  {'rating': 3,
#   'id': 5910,
#   'imdbid': '0023649',
#   'title': 'Vampyr',
#   'year': 1932},
#  {'year': 1932,
#   'title': 'Shanghai Express',
#   'id': 5929,
#   'imdbid': '0023458',
#   'rating': 3},
#  {'year': 1932,
#   'title': 'Three on a Match',
#   'id': 6051,
#   'imdbid': '0023590',
#   'rating': 3},
#  {'rating': 2,
#   'imdbid': '0023158',
#   'id': 6052,
#   'title': 'Love Me Tonight',
#   'year': 1932},
#  {'year': 1932,
#   'title': 'Scarface',
#   'id': 6063,
#   'imdbid': '0023427',
#   'rating': 1},
#  {'year': 1932,
#   'title': 'Red-Headed Woman',
#   'imdbid': '0023385',
#   'id': 6092,
#   'rating': 3},
#  {'id': 6176,
#   'imdbid': '0023935',
#   'rating': 1,
#   'year': 1932,
#   'title': 'Death Kiss, The'},
#  {'rating': 3,
#   'imdbid': '0023582',
#   'id': 6852,
#   'title': 'Thirteen Women',
#   'year': 1932},
#  {'title': 'Blue Light (Das Blaue Licht), The',
#   'year': 1932,
#   'rating': 1,
#   'imdbid': '0022694',
#   'id': 6990},
#  {'imdbid': '0023285',
#   'id': 7301,
#   'rating': 0,
#   'year': 1932,
#   'title': 'Number 17'},
#  {'title': 'Bitter Tea of General Yen, The',
#   'year': 1932,
#   'rating': 3,
#   'id': 10705,
#   'imdbid': '0023814'},
#  {'imdbid': '0024028',
#   'id': 802,
#   'rating': 3,
#   'year': 1933,
#   'title': 'Footlight Parade'},
#  {'year': 1933,
#   'title': 'Queen Christina',
#   'imdbid': '0024481',
#   'id': 1330,
#   'rating': 3},
#  {'rating': 1,
#   'imdbid': '0024473',
#   'id': 1248,
#   'title': 'Private Life of Henry VIII., The',
#   'year': 1933},
#  {'imdbid': '0024216',
#   'id': 2229,
#   'rating': 0,
#   'year': 1933,
#   'title': 'King Kong'},
#  {'rating': 3,
#   'imdbid': '0024264',
#   'id': 2231,
#   'title': 'Little Women',
#   'year': 1933},
#  {'id': 3188,
#   'imdbid': '0023753',
#   'rating': 3,
#   'year': 1933,
#   'title': 'Alice in Wonderland'},
#  {'year': 1933,
#   'title': 'Vampire Bat, The',
#   'id': 3210,
#   'imdbid': '0024727',
#   'rating': 3},
#  {'title': '42nd Street',
#   'year': 1933,
#   'rating': 3,
#   'id': 4335,
#   'imdbid': '0024034'},
#  {'title': 'Day of Reckoning',
#   'year': 1933,
#   'rating': 3,
#   'imdbid': '0023932',
#   'id': 5029},
#  {'year': 1933,
#   'title': 'Duck Soup',
#   'imdbid': '0023969',
#   'id': 5185,
#   'rating': 1},
#  {'year': 1933,
#   'title': 'Tomorrow at Seven',
#   'imdbid': '0024679',
#   'id': 5752,
#   'rating': 3},
#  {'title': 'Gold Diggers of 1933',
#   'year': 1933,
#   'rating': 3,
#   'imdbid': '0024069',
#   'id': 5916},
#  {'id': 6056,
#   'imdbid': '0024008',
#   'rating': 3,
#   'year': 1933,
#   'title': 'Female'},
#  {'id': 6193,
#   'imdbid': '0024625',
#   'rating': 3,
#   'year': 1933,
#   'title': 'A Study in Scarlet'},
#  {'year': 1933,
#   'title': 'Peanut Vendor, The',
#   'imdbid': '0024432',
#   'id': 6205,
#   'rating': 0},
#  {'imdbid': '0024184',
#   'id': 7450,
#   'rating': 1,
#   'year': 1933,
#   'title': 'Invisible Man, The'},
#  {'year': 1933,
#   'title': 'Baby Face',
#   'imdbid': '0023775',
#   'id': 7528,
#   'rating': 3},
#  {'id': 8346,
#   'imdbid': '0023940',
#   'rating': 1,
#   'year': 1933,
#   'title': 'Design for Living'},
#  {'rating': 3,
#   'imdbid': '0023876',
#   'id': 8477,
#   'title': 'Cavalcade',
#   'year': 1933},
#  {'id': 10492,
#   'imdbid': '0024210',
#   'rating': 1,
#   'year': 1933,
#   'title': 'Kennel Murder Case, The'},
#  {'id': 10702,
#   'imdbid': '0024548',
#   'rating': 2,
#   'year': 1933,
#   'title': 'She Done Him Wrong'},
#  {'imdbid': '0024601',
#   'id': 10714,
#   'rating': 3,
#   'year': 1933,
#   'title': 'Sons of the Desert'},
#  {'title': 'It Happened One Night',
#   'year': 1934,
#   'rating': 3,
#   'id': 621,
#   'imdbid': '0025316'},
#  {'rating': 1,
#   'imdbid': '0024961',
#   'id': 1324,
#   'title': 'Cat&#39;s-Paw, The',
#   'year': 1934},
#  {'title': 'Scarlet Empress, The',
#   'year': 1934,
#   'rating': 3,
#   'id': 1325,
#   'imdbid': '0025746'},
#  {'title': 'Painted Veil, The',
#   'year': 1934,
#   'rating': 1,
#   'id': 1329,
#   'imdbid': '0025617'},
#  {'imdbid': '0025004',
#   'id': 1246,
#   'rating': 1,
#   'year': 1934,
#   'title': 'Count of Monte Cristo, The'},
#  {'imdbid': '0024991',
#   'id': 1270,
#   'rating': 1,
#   'year': 1934,
#   'title': 'Cleopatra'},
#  {'imdbid': '0025586',
#   'id': 1379,
#   'rating': 1,
#   'year': 1934,
#   'title': 'Of Human Bondage'},
#  {'id': 1795,
#   'imdbid': '0024844',
#   'rating': 0,
#   'year': 1934,
#   'title': 'L&#39;atalante'},
#  {'id': 1969,
#   'imdbid': '0025423',
#   'rating': 0,
#   'year': 1934,
#   'title': 'Lost Patrol, The'},
#  {'imdbid': '0025822',
#   'id': 4443,
#   'rating': 3,
#   'year': 1934,
#   'title': 'Spitfire'},
#  {'rating': 3,
#   'imdbid': '0025465',
#   'id': 4702,
#   'title': 'Maniac',
#   'year': 1934},
#  {'title': 'Anne of Green Gables',
#   'year': 1934,
#   'rating': 3,
#   'id': 5319,
#   'imdbid': '0024831'},
#  {'rating': 2,
#   'imdbid': '0025424',
#   'id': 5523,
#   'title': 'Lost in the Stratosphere',
#   'year': 1934},
#  {'year': 1934,
#   'title': 'Search for Beauty',
#   'imdbid': '0025755',
#   'id': 5821,
#   'rating': 3},
#  {'rating': 3,
#   'imdbid': '0025091',
#   'id': 6772,
#   'title': 'Evelyn Prentice',
#   'year': 1934},
#  {'imdbid': '0025452',
#   'id': 7304,
#   'rating': 3,
#   'year': 1934,
#   'title': 'Man Who Knew Too Much, The'},
#  {'year': 1934,
#   'title': 'Imitation of Life',
#   'id': 7999,
#   'imdbid': '0025301',
#   'rating': 3},
#  {'year': 1934,
#   'title': 'Mystery Liner',
#   'id': 8653,
#   'imdbid': '0025543',
#   'rating': 0},
#  {'title': 'It&#39;s a Gift',
#   'year': 1934,
#   'rating': 3,
#   'imdbid': '0025318',
#   'id': 10824},
#  {'imdbid': '0027125',
#   'id': 595,
#   'rating': 2,
#   'year': 1935,
#   'title': 'Top Hat'},
#  {'imdbid': '0026029',
#   'id': 1242,
#   'rating': 3,
#   'year': 1935,
#   'title': '39 Steps, The'},
#  {'rating': 2,
#   'imdbid': '0026071',
#   'id': 1261,
#   'title': 'Anna Karenina',
#   'year': 1935},
#  {'id': 1361,
#   'imdbid': '0026752',
#   'rating': 1,
#   'year': 1935,
#   'title': 'Mutiny on the Bounty'},
#  {'imdbid': '0026768',
#   'id': 1685,
#   'rating': 3,
#   'year': 1935,
#   'title': 'Naughty Marietta'},
#  {'year': 1935,
#   'title': 'Roberta',
#   'id': 2362,
#   'imdbid': '0026942',
#   'rating': 3},
#  {'title': 'Magnificent Obsession',
#   'year': 1935,
#   'rating': 3,
#   'id': 2756,
#   'imdbid': '0026667'},
#  {'imdbid': '0026778',
#   'id': 3881,
#   'rating': 1,
#   'year': 1935,
#   'title': 'A Night At The Opera'},
#  {'title': 'Bride of Frankenstein, The',
#   'year': 1935,
#   'rating': 3,
#   'id': 3891,
#   'imdbid': '0026138'},
#  {'id': 5750,
#   'imdbid': '0026599',
#   'rating': 2,
#   'year': 1935,
#   'title': 'Lady in Scarlet, The'},
#  {'year': 1935,
#   'title': 'Riverside Murder, The',
#   'id': 5913,
#   'imdbid': '0026939',
#   'rating': 2},
#  {'year': 1935,
#   'title': 'Mad Love',
#   'imdbid': '0026663',
#   'id': 7998,
#   'rating': 2},
#  {'title': 'Swing Time',
#   'year': 1936,
#   'rating': 1,
#   'id': 596,
#   'imdbid': '0028333'},
#  {'rating': 0,
#   'id': 1323,
#   'imdbid': '0027977',
#   'title': 'Modern Times',
#   'year': 1936},
#  {'rating': 1,
#   'id': 1237,
#   'imdbid': '0027438',
#   'title': 'Charge of the Light Brigade, The',
#   'year': 1936},
#  {'year': 1936,
#   'title': 'San Francisco',
#   'imdbid': '0028216',
#   'id': 1359,
#   'rating': 1},
#  {'year': 1936,
#   'title': 'Wife vs. Secretary',
#   'id': 1360,
#   'imdbid': '0028505',
#   'rating': 2},
#  {'year': 1936,
#   'title': 'Petrified Forest, The',
#   'imdbid': '0028096',
#   'id': 1369,
#   'rating': 3},
#  {'rating': 3,
#   'id': 1992,
#   'imdbid': '0027996',
#   'title': 'Mr. Deeds Goes to Town',
#   'year': 1936},
#  {'year': 1936,
#   'title': 'Born to Dance',
#   'imdbid': '0027387',
#   'id': 2363,
#   'rating': 3},
#  {'year': 1936,
#   'title': 'Revolt of the Zombies',
#   'imdbid': '0028174',
#   'id': 2554,
#   'rating': 0},
#  {'rating': 1,
#   'imdbid': '0027562',
#   'id': 2699,
#   'title': 'Earthworm Tractors',
#   'year': 1936},
#  {'title': 'Osaka Elegy',
#   'year': 1936,
#   'rating': 3,
#   'id': 2853,
#   'imdbid': '0028021'},
#  {'rating': 3,
#   'imdbid': '0028355',
#   'id': 3280,
#   'title': 'Theodora Goes Wild',
#   'year': 1936},
#  {'title': 'Great Ziegfeld, The',
#   'year': 1936,
#   'rating': 3,
#   'imdbid': '0027698',
#   'id': 3401},
#  {'title': 'Mandarin Mystery, The',
#   'year': 1936,
#   'rating': 3,
#   'imdbid': '0029207',
#   'id': 3548},
#  {'rating': 3,
#   'imdbid': '0027752',
#   'id': 3560,
#   'title': 'Only Son, The',
#   'year': 1936},
#  {'title': 'Camille',
#   'year': 1936,
#   'rating': 3,
#   'imdbid': '0028683',
#   'id': 3598},
#  {'rating': 3,
#   'id': 4010,
#   'imdbid': '0028092',
#   'title': 'Pennies from Heaven',
#   'year': 1936},
#  {'id': 4069,
#   'imdbid': '0028203',
#   'rating': 3,
#   'year': 1936,
#   'title': 'Romeo and Juliet'},
#  {'year': 1936,
#   'title': 'Bullets or Ballots',
#   'id': 4143,
#   'imdbid': '0027407',
#   'rating': 3},
#  {'rating': 2,
#   'imdbid': '0028010',
#   'id': 5852,
#   'title': 'My Man Godfrey',
#   'year': 1936},
#  {'imdbid': '0028212',
#   'id': 5926,
#   'rating': 3,
#   'year': 1936,
#   'title': 'Sabotage'},
#  {'rating': 2, 'imdbid': '0027652', 'id': 6096, 'title': 'Fury', 'year': 1936},
#  {'rating': 3,
#   'imdbid': '0028000',
#   'id': 6174,
#   'title': 'Murder at Glen Athol',
#   'year': 1936},
#  {'rating': 0,
#   'id': 6210,
#   'imdbid': '3427056',
#   'title': 'Il caso Valdemar',
#   'year': 1936},
#  {'id': 7227,
#   'imdbid': '0028356',
#   'rating': 2,
#   'year': 1936,
#   'title': 'These Three'},
#  {'year': 1936,
#   'title': 'Secret Agent',
#   'imdbid': '0028231',
#   'id': 7308,
#   'rating': 3},
#  {'title': 'Dracula&#39;s Daughter',
#   'year': 1936,
#   'rating': 3,
#   'imdbid': '0027545',
#   'id': 7992},
#  {'rating': 1,
#   'imdbid': '0029546',
#   'id': 597,
#   'title': 'Shall We Dance',
#   'year': 1937},
#  {'id': 631,
#   'imdbid': '0029604',
#   'rating': 3,
#   'year': 1937,
#   'title': 'Stage Door'},
#  {'year': 1937,
#   'title': 'Stella Dallas',
#   'imdbid': '0029608',
#   'id': 795,
#   'rating': 3},
#  {'rating': 2,
#   'id': 1332,
#   'imdbid': '0028739',
#   'title': 'Conquest',
#   'year': 1937},
#  {'rating': 2,
#   'id': 1335,
#   'imdbid': '0029682',
#   'title': 'Topper',
#   'year': 1937},
#  {'title': 'Lost Horizon',
#   'year': 1937,
#   'rating': 2,
#   'imdbid': '0029162',
#   'id': 1336},
#  {'id': 1240,
#   'imdbid': '0029442',
#   'rating': 1,
#   'year': 1937,
#   'title': 'Prisoner of Zenda, The'},
#  {'imdbid': '0029087',
#   'id': 1244,
#   'rating': 2,
#   'year': 1937,
#   'title': 'Knight Without Armor'},
#  {'rating': 2,
#   'id': 1358,
#   'imdbid': '0029377',
#   'title': 'Parnell',
#   'year': 1937},
#  {'id': 1976,
#   'imdbid': '0029583',
#   'rating': 3,
#   'year': 1937,
#   'title': 'Snow White and the Seven Dwarfs'},
#  {'rating': 2,
#   'imdbid': '0028772',
#   'id': 2382,
#   'title': 'A Day at the Races',
#   'year': 1937},
#  {'title': 'Nothing Sacred',
#   'year': 1937,
#   'rating': 0,
#   'imdbid': '0029322',
#   'id': 3968},
#  {'rating': 3,
#   'imdbid': '0029192',
#   'id': 4255,
#   'title': 'Make Way for Tomorrow',
#   'year': 1937},
#  {'id': 5617,
#   'imdbid': '0029565',
#   'rating': 1,
#   'year': 1937,
#   'title': 'Murder at the Baskervilles (Silver Blaze)'},
#  {'year': 1937,
#   'title': 'Pepe le Moko',
#   'id': 5740,
#   'imdbid': '0029453',
#   'rating': 2},
#  {'year': 1937,
#   'title': 'Awful Truth, The',
#   'imdbid': '0028597',
#   'id': 6554,
#   'rating': 3},
#  {'rating': 3,
#   'imdbid': '0029811',
#   'id': 7317,
#   'title': 'Girl Was Young, The',
#   'year': 1937},
#  {'year': 1937,
#   'title': 'Marked Woman',
#   'id': 7877,
#   'imdbid': '0029217',
#   'rating': 3},
#  {'imdbid': '0027552',
#   'id': 8473,
#   'rating': 3,
#   'year': 1937,
#   'title': 'Bizarre, Bizarre'},
#  {'imdbid': '0029146',
#   'id': 8478,
#   'rating': 1,
#   'year': 1937,
#   'title': 'Life of Emile Zola, The'},
#  {'rating': 3,
#   'imdbid': '0029751',
#   'id': 10352,
#   'title': 'Wee Willie Winkie',
#   'year': 1937},
#  {'imdbid': '0028691',
#   'id': 10838,
#   'rating': 0,
#   'year': 1937,
#   'title': 'Captains Courageous'},
#  {'id': 594,
#   'imdbid': '0029971',
#   'rating': 2,
#   'year': 1938,
#   'title': 'Carefree'},
#  {'rating': 3,
#   'id': 620,
#   'imdbid': '0030341',
#   'title': 'Lady Vanishes, The',
#   'year': 1938},
#  {'title': 'Holiday',
#   'year': 1938,
#   'rating': 3,
#   'imdbid': '0030241',
#   'id': 994},
#  {'year': 1938,
#   'title': 'Dawn Patrol, The',
#   'imdbid': '0030044',
#   'id': 1238,
#   'rating': 0},
#  {'imdbid': '0030287',
#   'id': 1367,
#   'rating': 2,
#   'year': 1938,
#   'title': 'Jezebel'},
#  {'title': 'Sisters, The',
#   'year': 1938,
#   'rating': 2,
#   'imdbid': '0030755',
#   'id': 1378},
#  {'rating': 0,
#   'id': 2467,
#   'imdbid': '0029942',
#   'title': 'Boys Town',
#   'year': 1938},
#  {'rating': 1,
#   'imdbid': '0030473',
#   'id': 2590,
#   'title': 'Mr. Wong, Detective',
#   'year': 1938},
#  {'year': 1938,
#   'title': 'Adventures of Robin Hood, The',
#   'id': 3103,
#   'imdbid': '0029843',
#   'rating': 2},
#  {'id': 3283,
#   'imdbid': '0029929',
#   'rating': 2,
#   'year': 1938,
#   'title': 'Bluebeard&#39;s Eighth Wife'},
#  {'imdbid': '0029947',
#   'id': 3400,
#   'rating': 3,
#   'year': 1938,
#   'title': 'Bringing Up Baby'},
#  {'title': 'Four Daughters',
#   'year': 1938,
#   'rating': 3,
#   'id': 3951,
#   'imdbid': '0030149'},
#  {'year': 1938,
#   'title': 'Mad Miss Manton, The',
#   'id': 4495,
#   'imdbid': '0030396',
#   'rating': 3},
#  {'title': 'Baker&#39;s Wife, The',
#   'year': 1938,
#   'rating': 1,
#   'id': 6042,
#   'imdbid': '0030127'},
#  {'title': 'Angels with Dirty Faces',
#   'year': 1938,
#   'rating': 1,
#   'imdbid': '0029870',
#   'id': 7290},
#  {'title': 'Wizard of Oz, The',
#   'year': 1939,
#   'rating': 3,
#   'id': 174,
#   'imdbid': '0032138'},
#  {'title': 'Gone with the Wind',
#   'year': 1939,
#   'rating': 3,
#   'id': 291,
#   'imdbid': '0031381'},
#  {'year': 1939,
#   'title': 'Dodge City',
#   'id': 383,
#   'imdbid': '0031235',
#   'rating': 2},
#  {'rating': 3,
#   'imdbid': '0032143',
#   'id': 588,
#   'title': 'Women, The',
#   'year': 1939},
#  {'year': 1939,
#   'title': 'Stagecoach',
#   'id': 593,
#   'imdbid': '0031971',
#   'rating': 3},
#  {'imdbid': '0032145',
#   'id': 1239,
#   'rating': 2,
#   'year': 1939,
#   'title': 'Wuthering Heights'},
#  {'id': 1245,
#   'imdbid': '0031385',
#   'rating': 2,
#   'year': 1939,
#   'title': 'Goodbye, Mr. Chips'},
#  {'year': 1939,
#   'title': 'Ninotchka',
#   'imdbid': '0031725',
#   'id': 1259,
#   'rating': 3},
#  {'title': 'Juarez',
#   'year': 1939,
#   'rating': 2,
#   'imdbid': '0031516',
#   'id': 1368},
#  {'imdbid': '0031210',
#   'id': 1370,
#   'rating': 3,
#   'year': 1939,
#   'title': 'Dark Victory'},
#  {'year': 1939,
#   'title': 'Essex and Elizabeth',
#   'id': 1371,
#   'imdbid': '0031826',
#   'rating': 2},
#  {'title': 'Young Mr. Lincoln',
#   'year': 1939,
#   'rating': 2,
#   'imdbid': '0032155',
#   'id': 1382},
#  {'title': 'Jesse James',
#   'year': 1939,
#   'rating': 2,
#   'imdbid': '0031507',
#   'id': 1383},
#  {'title': 'Drums Along the Mohawk',
#   'year': 1939,
#   'rating': 2,
#   'imdbid': '0031252',
#   'id': 1384},
#  {'title': 'Story of Alexander Graham Bell, The',
#   'year': 1939,
#   'rating': 2,
#   'imdbid': '0031981',
#   'id': 1385},
#  {'imdbid': '0031322',
#   'id': 1973,
#   'rating': 0,
#   'year': 1939,
#   'title': 'Flying Deuces, The'},
#  {'title': 'Hunchback of Notre Dame, The',
#   'year': 1939,
#   'rating': 0,
#   'id': 2086,
#   'imdbid': '0031455'},
#  {'id': 2372,
#   'imdbid': '0031060',
#   'rating': 2,
#   'year': 1939,
#   'title': 'At the Circus'},
#  {'year': 1939,
#   'title': 'Gorilla, The',
#   'id': 2555,
#   'imdbid': '0031387',
#   'rating': 3},
#  {'year': 1939,
#   'title': 'Mr. Wong in Chinatown',
#   'imdbid': '0031680',
#   'id': 2622,
#   'rating': 1},
#  {'rating': 1,
#   'imdbid': '0031742',
#   'id': 2851,
#   'title': 'Of Mice and Men',
#   'year': 1939},
#  {'rating': 3,
#   'imdbid': '0031885',
#   'id': 3089,
#   'title': 'Rules of the Game, The',
#   'year': 1939},
#  {'year': 1939,
#   'title': 'Babes in Arms',
#   'imdbid': '0031066',
#   'id': 3723,
#   'rating': 3},
#  {'year': 1939,
#   'title': 'Destry Rides Again',
#   'id': 5634,
#   'imdbid': '0031225',
#   'rating': 3},
#  {'id': 5763,
#   'imdbid': '0031709',
#   'rating': 3,
#   'year': 1939,
#   'title': 'Nancy Drew... Reporter'},
#  {'title': 'Adventures of Sherlock Holmes, The',
#   'year': 1939,
#   'rating': 3,
#   'imdbid': '0031022',
#   'id': 5863},
#  {'rating': 2,
#   'imdbid': '0031679',
#   'id': 5946,
#   'title': 'Mr. Smith Goes to Washington',
#   'year': 1939},
#  {'rating': 3,
#   'imdbid': '0031505',
#   'id': 7322,
#   'title': 'Jamaica Inn',
#   'year': 1939},
#  {'year': 1939,
#   'title': 'Le jour se l&egrave;ve',
#   'id': 8098,
#   'imdbid': '0031514',
#   'rating': 2},
#  {'rating': 0,
#   'imdbid': '0031397',
#   'id': 8511,
#   'title': 'Gulliver&#39;s Travels',
#   'year': 1939},
#  {'rating': 3,
#   'id': 9038,
#   'imdbid': '0031593',
#   'title': 'Love Affair',
#   'year': 1939},
#  {'title': 'Gunga Din',
#   'year': 1939,
#   'rating': 0,
#   'id': 10848,
#   'imdbid': '0031398'},
#  {'title': 'Only Angels Have Wings',
#   'year': 1939,
#   'rating': 2,
#   'imdbid': '0031762',
#   'id': 10880},
#  {'id': 478,
#   'imdbid': '0032910',
#   'rating': 1,
#   'year': 1940,
#   'title': 'Pinocchio'},
#  {'rating': 3,
#   'imdbid': '0032976',
#   'id': 618,
#   'title': 'Rebecca',
#   'year': 1940},
#  {'id': 1265,
#   'imdbid': '0033152',
#   'rating': 0,
#   'year': 1940,
#   'title': 'Thief of Bagdad, The'},
#  {'rating': 3,
#   'id': 1501,
#   'imdbid': '0032811',
#   'title': 'Mortal Storm, The',
#   'year': 1940},
#  {'year': 1940,
#   'title': 'Comrade X',
#   'imdbid': '0032349',
#   'id': 1355,
#   'rating': 2},
#  {'year': 1940,
#   'title': 'Boom Town',
#   'imdbid': '0032273',
#   'id': 1356,
#   'rating': 1},
#  {'year': 1940,
#   'title': 'Strange Cargo',
#   'imdbid': '0033105',
#   'id': 1357,
#   'rating': 0},
#  {'rating': 0,
#   'id': 1366,
#   'imdbid': '0032983',
#   'title': 'Return of Frank James, The',
#   'year': 1940},
#  {'rating': 2,
#   'id': 1373,
#   'imdbid': '0032194',
#   'title': 'All This, and Heaven Too',
#   'year': 1940},
#  {'title': 'Letter, The',
#   'year': 1940,
#   'rating': 2,
#   'imdbid': '0032701',
#   'id': 1380},
#  {'title': 'Grapes of Wrath, The',
#   'year': 1940,
#   'rating': 3,
#   'imdbid': '0032551',
#   'id': 1387},
#  {'title': 'A Chump at Oxford',
#   'year': 1940,
#   'rating': 0,
#   'id': 1975,
#   'imdbid': '0032339'},
#  {'title': 'Ape, The',
#   'year': 1940,
#   'rating': 3,
#   'imdbid': '0032215',
#   'id': 2556},
#  {'title': 'Santa Fe Trail',
#   'year': 1940,
#   'rating': 1,
#   'imdbid': '0033021',
#   'id': 2678},
#  {'rating': 3,
#   'imdbid': '0032599',
#   'id': 3033,
# ...
#   'rating': 3},
#  {'id': 4896,
#   'imdbid': '0048605',
#   'rating': 1,
#   'year': 1955,
#   'title': 'Seven Year Itch, The'},
#  {'imdbid': '0048673',
#   'id': 5165,
#   'rating': 3,
#   'year': 1955,
#   'title': 'Summertime'},
#  {'rating': 1,
#   'imdbid': '0048254',
#   'id': 5403,
#   'title': 'Killer&#39;s Kiss',
#   'year': 1955},
#  {'title': 'Pather Panchali',
#   'year': 1955,
#   'rating': 3,
#   'imdbid': '0048473',
#   'id': 5471},
#  {'title': 'Godzilla Raids Again',
#   'year': 1955,
#   'rating': 2,
#   'imdbid': '0048127',
#   'id': 6055},
#  {'rating': 0,
#   'id': 6468,
#   'imdbid': '0047577',
#   'title': 'This Island Earth',
#   'year': 1955},
#  {'year': 1955,
#   'title': 'Glass Slipper, The',
#   'imdbid': '0048124',
#   'id': 6481,
#   'rating': 3},
#  {'rating': 3,
#   'id': 6615,
#   'imdbid': '0048401',
#   'title': 'My Sister Eileen',
#   'year': 1955},
#  {'title': 'Prisoner, The',
#   'year': 1955,
#   'rating': 0,
#   'id': 7262,
#   'imdbid': '0048512'},
#  {'year': 1955,
#   'title': 'Trouble with Harry, The',
#   'imdbid': '0048750',
#   'id': 7360,
#   'rating': 2},
#  {'year': 1955,
#   'title': 'Prodigal, The',
#   'id': 7797,
#   'imdbid': '0048517',
#   'rating': 3},
#  {'year': 1955,
#   'title': 'Les grandes manoeuvres',
#   'id': 7878,
#   'imdbid': '0048133',
#   'rating': 3},
#  {'id': 8014,
#   'imdbid': '0048432',
#   'rating': 2,
#   'year': 1955,
#   'title': 'Not as a Stranger'},
#  {'rating': 3,
#   'imdbid': '0047821',
#   'id': 10340,
#   'title': 'Le amiche',
#   'year': 1955},
#  {'year': 1955,
#   'title': 'All That Heaven Allows',
#   'id': 10342,
#   'imdbid': '0047811',
#   'rating': 3},
#  {'title': 'Lola Mont&egrave;s',
#   'year': 1955,
#   'rating': 3,
#   'id': 10354,
#   'imdbid': '0048308'},
#  {'title': 'Bad Day at Black Rock',
#   'year': 1955,
#   'rating': 0,
#   'id': 10527,
#   'imdbid': '0047849'},
#  {'rating': 3,
#   'imdbid': '0049674',
#   'id': 10662,
#   'title': 'Richard III',
#   'year': 1955},
#  {'year': 1955,
#   'title': 'School for Love',
#   'id': 10781,
#   'imdbid': '0048103',
#   'rating': 3},
#  {'imdbid': '0048342',
#   'id': 11179,
#   'rating': 2,
#   'year': 1955,
#   'title': 'Man from Laramie, The'},
#  {'title': 'Searchers, The',
#   'year': 1956,
#   'rating': 3,
#   'id': 357,
#   'imdbid': '0049730'},
#  {'imdbid': '0049787',
#   'id': 1559,
#   'rating': 2,
#   'year': 1956,
#   'title': 'Spanish Gardener, The'},
#  {'rating': 3,
#   'imdbid': '0048977',
#   'id': 1216,
#   'title': 'Bad Seed, The',
#   'year': 1956},
#  {'year': 1956,
#   'title': 'King and I, The',
#   'imdbid': '0049408',
#   'id': 1092,
#   'rating': 2},
#  {'rating': 1,
#   'id': 1545,
#   'imdbid': '0049369',
#   'title': 'Iron Petticoat, The',
#   'year': 1956},
#  {'title': 'Wrong Man, The',
#   'year': 1956,
#   'rating': 1,
#   'imdbid': '0051207',
#   'id': 2219},
#  {'title': 'Forbidden Planet',
#   'year': 1956,
#   'rating': 0,
#   'imdbid': '0049223',
#   'id': 2306},
#  {'title': 'Gunslinger',
#   'year': 1956,
#   'rating': 3,
#   'imdbid': '0049287',
#   'id': 2647},
#  {'rating': 3,
#   'imdbid': '0049366',
#   'id': 2698,
#   'title': 'Invasion of the Body Snatchers',
#   'year': 1956},
#  {'rating': 2,
#   'imdbid': '0049096',
#   'id': 2730,
#   'title': 'Court Jester, The',
#   'year': 1956},
#  {'title': 'War and Peace',
#   'year': 1956,
#   'rating': 3,
#   'id': 2861,
#   'imdbid': '0049934'},
#  {'title': 'Bigger Than Life',
#   'year': 1956,
#   'rating': 0,
#   'id': 2904,
#   'imdbid': '0049010'},
#  {'rating': 2,
#   'id': 3076,
#   'imdbid': '0049833',
#   'title': 'Ten Commandments, The',
#   'year': 1956},
#  {'title': '...And God Created Woman',
#   'year': 1956,
#   'rating': 3,
#   'imdbid': '0049189',
#   'id': 3409},
#  {'rating': 0,
#   'imdbid': '0048960',
#   'id': 3981,
#   'title': 'Around the World in Eighty Days',
#   'year': 1956},
#  {'title': 'Proud and Profane, The',
#   'year': 1956,
#   'rating': 3,
#   'imdbid': '0049640',
#   'id': 4245},
#  {'title': 'Indestructible Man',
#   'year': 1956,
#   'rating': 1,
#   'imdbid': '0049363',
#   'id': 4402},
#  {'rating': 3,
#   'id': 4670,
#   'imdbid': '0049038',
#   'title': 'Bus Stop',
#   'year': 1956},
#  {'year': 1956,
#   'title': 'Killing, The',
#   'id': 5414,
#   'imdbid': '0049406',
#   'rating': 1},
#  {'imdbid': '0048956',
#   'id': 5470,
#   'rating': 3,
#   'year': 1956,
#   'title': 'Aparajito'},
#  {'title': 'Un condamne a mort s&#39;est echappe ou Le vent souffle ou il veut',
#   'year': 1956,
#   'rating': 0,
#   'imdbid': '0049902',
#   'id': 5555},
#  {'rating': 1,
#   'imdbid': '0049782',
#   'id': 6064,
#   'title': 'Rodan',
#   'year': 1956},
#  {'rating': 3,
#   'id': 6308,
#   'imdbid': '0049471',
#   'title': 'Man Who Never Was, The',
#   'year': 1956},
#  {'year': 1956,
#   'title': 'High Society',
#   'imdbid': '0049314',
#   'id': 6641,
#   'rating': 3},
#  {'year': 1956,
#   'title': 'Calle mayor [Main Street]',
#   'id': 7394,
#   'imdbid': '0049043',
#   'rating': 3},
#  {'id': 7442,
#   'imdbid': '0049470',
#   'rating': 2,
#   'year': 1956,
#   'title': 'Man Who Knew Too Much, The'},
#  {'rating': 3,
#   'imdbid': '0049537',
#   'id': 8314,
#   'title': 'Flowing',
#   'year': 1956},
#  {'year': 1956,
#   'title': 'Unguarded Moment, The',
#   'id': 8358,
#   'imdbid': '0049904',
#   'rating': 1},
#  {'year': 1956,
#   'title': 'Eyewitness',
#   'imdbid': '0049196',
#   'id': 8398,
#   'rating': 3},
#  {'year': 1956,
#   'title': 'Sissi - The Young Empress',
#   'id': 8872,
#   'imdbid': '0049762',
#   'rating': 3},
#  {'title': 'La banda degli onesti',
#   'year': 1956,
#   'rating': 2,
#   'id': 9055,
#   'imdbid': '0048981'},
#  {'title': 'Captain from Kopenick, The',
#   'year': 1956,
#   'rating': 1,
#   'imdbid': '0049293',
#   'id': 9719},
#  {'imdbid': '0049095',
#   'id': 9993,
#   'rating': 3,
#   'year': 1956,
#   'title': 'Le coup du berger'},
#  {'title': 'Autumn Leaves',
#   'year': 1956,
#   'rating': 3,
#   'imdbid': '0048967',
#   'id': 10346},
#  {'rating': 3,
#   'id': 10348,
#   'imdbid': '0048973',
#   'title': 'Baby Doll',
#   'year': 1956},
#  {'title': 'Yield to the Night',
#   'year': 1956,
#   'rating': 3,
#   'id': 10623,
#   'imdbid': '0049019'},
#  {'imdbid': '0049452',
#   'id': 10760,
#   'rating': 2,
#   'year': 1956,
#   'title': 'Love Me Tender'},
#  {'imdbid': '0049483',
#   'id': 10780,
#   'rating': 3,
#   'year': 1956,
#   'title': 'Her Bridal Night'},
#  {'id': 11091,
#   'imdbid': '0049370',
#   'rating': 3,
#   'year': 1956,
#   'title': 'It Conquered the World'},
#  {'imdbid': '0049743',
#   'id': 11190,
#   'rating': 1,
#   'year': 1956,
#   'title': '7 Men from Now'},
#  {'title': 'Giant',
#   'year': 1956,
#   'rating': 3,
#   'imdbid': '0049261',
#   'id': 11461},
#  {'year': 1957,
#   'title': '12 Angry Men',
#   'imdbid': '0050083',
#   'id': 302,
#   'rating': 0},
#  {'rating': 2,
#   'imdbid': '0051114',
#   'id': 965,
#   'title': 'True Story of Jesse James, The',
#   'year': 1957},
#  {'rating': 3,
#   'id': 993,
#   'imdbid': '0050307',
#   'title': 'Desk Set',
#   'year': 1957},
#  {'id': 1015,
#   'imdbid': '0050634',
#   'rating': 3,
#   'year': 1957,
#   'title': 'Cranes Are Flying, The'},
#  {'rating': 0,
#   'imdbid': '0050539',
#   'id': 1291,
#   'title': 'Incredible Shrinking Man, The',
#   'year': 1957},
#  {'rating': 0,
#   'imdbid': '0050825',
#   'id': 1274,
#   'title': 'Paths of Glory',
#   'year': 1957},
#  {'imdbid': '0050798',
#   'id': 1121,
#   'rating': 1,
#   'year': 1957,
#   'title': 'Old Yeller'},
#  {'year': 1957,
#   'title': 'Three Faces of Eve',
#   'imdbid': '0051077',
#   'id': 1660,
#   'rating': 0},
#  {'title': 'Funny Face',
#   'year': 1957,
#   'rating': 3,
#   'id': 1747,
#   'imdbid': '0050419'},
#  {'title': 'Nights of Cabiria',
#   'year': 1957,
#   'rating': 3,
#   'imdbid': '0050783',
#   'id': 1765},
#  {'title': 'Kanal',
#   'year': 1957,
#   'rating': 1,
#   'id': 1800,
#   'imdbid': '0050585'},
#  {'year': 1957,
#   'title': 'Enemy Below, The',
#   'id': 1989,
#   'imdbid': '0050356',
#   'rating': 0},
#  {'title': 'Seventh Seal, The',
#   'year': 1957,
#   'rating': 1,
#   'imdbid': '0050976',
#   'id': 2043},
#  {'title': 'Night of the Demon',
#   'year': 1957,
#   'rating': 3,
#   'id': 2160,
#   'imdbid': '0050766'},
#  {'id': 2301,
#   'imdbid': '0051036',
#   'rating': 1,
#   'year': 1957,
#   'title': 'Sweet Smell of Success'},
#  {'title': 'Fire Down Below',
#   'year': 1957,
#   'rating': 0,
#   'id': 2420,
#   'imdbid': '0050397'},
#  {'year': 1957,
#   'title': 'Heaven Knows, Mr. Allison',
#   'imdbid': '0050490',
#   'id': 2429,
#   'rating': 0},
#  {'year': 1957,
#   'title': 'Smultronst&auml;llet (Wild Strawberries)',
#   'id': 2520,
#   'imdbid': '0050986',
#   'rating': 2},
#  {'id': 2578,
#   'imdbid': '0050933',
#   'rating': 2,
#   'year': 1957,
#   'title': 'Sayonara'},
#  {'year': 1957,
#   'title': 'Tammy and the Bachelor',
#   'id': 2895,
#   'imdbid': '0051051',
#   'rating': 3},
#  {'year': 1957,
#   'title': 'Bridge on the River Kwai, The',
#   'imdbid': '0050212',
#   'id': 2981,
#   'rating': 1},
#  {'year': 1957,
#   'title': 'Prince and the Showgirl, The',
#   'id': 3007,
#   'imdbid': '0050861',
#   'rating': 3},
#  {'title': 'An Affair to Remember',
#   'year': 1957,
#   'rating': 2,
#   'imdbid': '0050105',
#   'id': 3429},
#  {'rating': 1,
#   'id': 3994,
#   'imdbid': '0050792',
#   'title': 'Oedipus Rex',
#   'year': 1957},
#  {'imdbid': '0050371',
#   'id': 4552,
#   'rating': 1,
#   'year': 1957,
#   'title': 'A Face in the Crowd'},
#  {'title': 'Sorority Girl',
#   'year': 1957,
#   'rating': 3,
#   'imdbid': '0050998',
#   'id': 4559},
#  {'rating': 1,
#   'imdbid': '0051201',
#   'id': 4933,
#   'title': 'Witness for the Prosecution',
#   'year': 1957},
#  {'year': 1957,
#   'title': 'Mysterians, The',
#   'id': 6624,
#   'imdbid': '0050251',
#   'rating': 3},
#  {'rating': 2,
#   'imdbid': '0050599',
#   'id': 7017,
#   'title': 'Kiss Them for Me',
#   'year': 1957},
#  {'year': 1957,
#   'title': 'Forty Guns',
#   'imdbid': '0050407',
#   'id': 7136,
#   'rating': 2},
#  {'title': 'Throne of Blood',
#   'year': 1957,
#   'rating': 0,
#   'imdbid': '0050613',
#   'id': 7165},
#  {'imdbid': '0050116',
#   'id': 7420,
#   'rating': 3,
#   'year': 1957,
#   'title': 'Amanecer en Puerta Oscura'},
#  {'rating': 3,
#   'imdbid': '0051151',
#   'id': 8321,
#   'title': 'El vampiro',
#   'year': 1957},
#  {'year': 1957,
#   'title': 'Island in the Sun',
#   'id': 8685,
#   'imdbid': '0050549',
#   'rating': 3},
#  {'rating': 0,
#   'id': 8736,
#   'imdbid': '0050610',
#   'title': 'Kronos',
#   'year': 1957},
#  {'title': 'Danger stalks near',
#   'year': 1957,
#   'rating': 3,
#   'id': 9006,
#   'imdbid': '0050421'},
#  {'year': 1957,
#   'title': 'La Parisienne',
#   'imdbid': '0051133',
#   'id': 10475,
#   'rating': 2},
#  {'title': 'Guns of Fort Petticoat, The',
#   'year': 1957,
#   'rating': 2,
#   'imdbid': '0050470',
#   'id': 10594},
#  {'rating': 1,
#   'imdbid': '0052357',
#   'id': 609,
#   'title': 'Vertigo',
#   'year': 1958},
#  {'year': 1958,
#   'title': 'M&auml;dchen in Uniform',
#   'imdbid': '0051964',
#   'id': 1572,
#   'rating': 3},
#  {'year': 1958,
#   'title': 'Fabulous World of Jules Verne, The',
#   'id': 1247,
#   'imdbid': '0052374',
#   'rating': 0},
#  {'rating': 2,
#   'id': 1255,
#   'imdbid': '0052365',
#   'title': 'Vikings, The',
#   'year': 1958},
#  {'title': 'Run Silent Run Deep',
#   'year': 1958,
#   'rating': 0,
#   'imdbid': '0052151',
#   'id': 1363},
#  {'year': 1958,
#   'title': 'Teacher&#39;s Pet',
#   'imdbid': '0052278',
#   'id': 1364,
#   'rating': 1},
#  {'imdbid': '0051622',
#   'id': 2281,
#   'rating': 2,
#   'year': 1958,
#   'title': 'Fly, The'},
#  {'id': 2373,
#   'imdbid': '0051951',
#   'rating': 1,
#   'year': 1958,
#   'title': 'Day the Sky Exploded, The'},
#  {'imdbid': '0051554',
#   'id': 2476,
#   'rating': 3,
#   'year': 1958,
#   'title': 'Dracula (Horror of Dracula)'},
#  {'id': 2585,
#   'imdbid': '0052394',
#   'rating': 3,
#   'year': 1958,
#   'title': 'Wild Women of Wongo, The'},
#  {'year': 1958,
#   'title': 'Screaming Skull, The',
#   'id': 2763,
#   'imdbid': '0052169',
#   'rating': 2},
#  {'title': 'Mon Oncle',
#   'year': 1958,
#   'rating': 3,
#   'imdbid': '0050706',
#   'id': 2823},
#  {'id': 3146,
#   'imdbid': '0052311',
#   'rating': 1,
#   'year': 1958,
#   'title': 'Touch of Evil'},
#  {'title': 'Gigi', 'year': 1958, 'rating': 2, 'imdbid': '0051658', 'id': 3056},
#  {'id': 3238,
#   'imdbid': '0051525',
#   'rating': 0,
#   'year': 1958,
#   'title': 'Defiant Ones, The'},
#  {'id': 3321,
#   'imdbid': '0051383',
#   'rating': 3,
#   'year': 1958,
#   'title': 'Auntie Mame'},
#  {'title': 'Separate Tables',
#   'year': 1958,
#   'rating': 3,
#   'imdbid': '0052182',
#   'id': 3926},
#  {'imdbid': '0052225',
#   'id': 3977,
#   'rating': 3,
#   'year': 1958,
#   'title': 'South Pacific'},
#  {'title': 'Indiscreet',
#   'year': 1958,
#   'rating': 3,
#   'imdbid': '0051773',
#   'id': 4211},
#  {'rating': 1,
#   'id': 4410,
#   'imdbid': '0051755',
#   'title': 'I Bury the Living',
#   'year': 1958},
#  {'year': 1958,
#   'title': 'Inn of the Sixth Happiness, The',
#   'id': 4849,
#   'imdbid': '0051776',
#   'rating': 3},
#  {'imdbid': '0051459',
#   'id': 6012,
#   'rating': 3,
#   'year': 1958,
#   'title': 'Cat on a Hot Tin Roof'},
#  {'imdbid': '0051579',
#   'id': 6938,
#   'rating': 3,
#   'year': 1958,
#   'title': 'Love Is My Profession'},
#  {'id': 7054,
#   'imdbid': '0051422',
#   'rating': 0,
#   'year': 1958,
#   'title': 'Blood of the Vampire'},
#  {'rating': 0,
#   'imdbid': '0051808',
#   'id': 7135,
#   'title': 'Hidden Fortress, The',
#   'year': 1958},
#  {'title': 'It! The Terror from Beyond Space',
#   'year': 1958,
#   'rating': 1,
#   'imdbid': '0051786',
#   'id': 7606},
#  {'imdbid': '0052017',
#   'id': 8344,
#   'rating': 3,
#   'year': 1958,
#   'title': 'Brink of Life'},
#  {'imdbid': '0051758',
#   'id': 8450,
#   'rating': 3,
#   'year': 1958,
#   'title': 'I Want To Live!'},
#  {'year': 1958,
#   'title': 'Marjorie Morningstar',
#   'id': 10341,
#   'imdbid': '0051911',
#   'rating': 3},
#  {'rating': 2,
#   'id': 10521,
#   'imdbid': '0052218',
#   'title': 'Some Came Running',
#   'year': 1958},
#  {'year': 1958,
#   'title': 'Female, The',
#   'imdbid': '0051608',
#   'id': 10562,
#   'rating': 2},
#  {'year': 1958,
#   'title': 'King Creole',
#   'imdbid': '0051818',
#   'id': 10570,
#   'rating': 1},
#  {'year': 1958,
#   'title': 'Night Heaven Fell, The',
#   'imdbid': '0050193',
#   'id': 10789,
#   'rating': 3},
#  {'title': 'Damn Yankees',
#   'year': 1958,
#   'rating': 2,
#   'imdbid': '0051516',
#   'id': 11495},
#  {'title': '400 Blows, The',
#   'year': 1959,
#   'rating': 0,
#   'id': 236,
#   'imdbid': '0053198'},
#  {'imdbid': '53285',
#   'id': 474,
#   'rating': 3,
#   'year': 1959,
#   'title': 'Sleeping Beauty'},
#  {'id': 1419,
#   'imdbid': '0052618',
#   'rating': 3,
#   'year': 1959,
#   'title': 'Ben-Hur'},
#  {'id': 1256,
#   'imdbid': '0052948',
#   'rating': 1,
#   'year': 1959,
#   'title': 'Journey to the Center of the Earth'},
#  {'rating': 3,
#   'imdbid': '0053131',
#   'id': 1555,
#   'title': 'Nun&#39;s Story, The',
#   'year': 1959},
#  {'year': 1959,
#   'title': 'Darby O&#39;Gill and the Little People',
#   'id': 1591,
#   'imdbid': '0052722',
#   'rating': 3},
#  {'rating': 3,
#   'id': 2023,
#   'imdbid': '0053291',
#   'title': 'Some Like It Hot',
#   'year': 1959},
#  {'rating': 3,
#   'id': 2095,
#   'imdbid': '0052918',
#   'title': 'Imitation of Life',
#   'year': 1959},
#  {'rating': 1,
#   'imdbid': '0053125',
#   'id': 2228,
#   'title': 'North By Northwest',
#   'year': 1959},
#  {'id': 2645,
#   'imdbid': '0053318',
#   'rating': 3,
#   'year': 1959,
#   'title': 'Suddenly, Last Summer'},
#  {'year': 1959,
#   'title': 'Giant Gila Monster, The',
#   'id': 2796,
#   'imdbid': '0052846',
#   'rating': 3},
#  {'year': 1959,
#   'title': 'Araya',
#   'id': 3119,
#   'imdbid': '0051372',
#   'rating': 3},
#  {'title': 'Tingler, The',
#   'year': 1959,
#   'rating': 1,
#   'imdbid': '0053363',
#   'id': 3166},
#  {'title': 'Come Dance with Me!',
#   'year': 1959,
#   'rating': 3,
#   'id': 3442,
#   'imdbid': '0053428'},
#  {'rating': 3,
#   'imdbid': '0053134',
#   'id': 3525,
#   'title': 'Good Morning (Ohay&ocirc;)',
#   'year': 1959},
#  {'rating': 1,
#   'id': 3608,
#   'imdbid': '0052861',
#   'title': 'Great War, The',
#   'year': 1959},
#  ...]
#        rating     id    imdbid                       title  year
# 0           0   9602   3155794            Passage de Venus  1874
# 1           0   9804  14495706           La Rosace Magique  1877
# 2           0   9603   2221420  Sallie Gardner at a Gallop  1878
# 3           0   9806  12592084           Le singe musicien  1878
# 4           0   9816   7816420     Athlete Swinging a Pick  1881
# ...       ...    ...       ...                         ...   ...
# 10442       3  11507  27410895                      Let go  2024
# 10443       1  11508   9218128                Gladiator II  2024
# 10444       3  11509   1262426              Wicked: Part 1  2024
# 10445       2  11510  31807233                   Her story  2024
# 10446       1  11513  24176060                       Queer  2024
#
# [10447 rows x 5 columns]

# %%
# 3. Aperçu initial des données :

print(data.head())  # Affiche les 5 premières lignes
print(data.info())  # Donne des informations sur les types de colonnes et les valeurs manquantes
print(data.describe())  # Statistiques descriptives basiques (numériques uniquement)
# Out:
#    rating    id    imdbid                       title  year
# 0       0  9602   3155794            Passage de Venus  1874
# 1       0  9804  14495706           La Rosace Magique  1877
# 2       0  9603   2221420  Sallie Gardner at a Gallop  1878
# 3       0  9806  12592084           Le singe musicien  1878
# 4       0  9816   7816420     Athlete Swinging a Pick  1881
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10447 entries, 0 to 10446
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rating  10447 non-null  int64
#  1   id      10447 non-null  int64
#  2   imdbid  10447 non-null  object
#  3   title   10447 non-null  object
#  4   year    10447 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 408.2+ KB
# None
#              rating            id          year
# count  10447.000000  10447.000000  10447.000000
# mean       2.135733   5586.786254   1997.041256
# std        1.098775   3276.820216     25.077329
# min        0.000000      1.000000   1874.000000
# 25%        1.000000   2722.500000   1989.000000
# 50%        3.000000   5539.000000   2006.000000
# 75%        3.000000   8430.500000   2014.000000
# max        3.000000  11513.000000   2024.000000

# %% [markdown]
# # Étape 2 : Inspection des Données

# %%
# 1. Vérification des dimensions :

print(data.shape)  # Nombre de lignes et de colonnes

# 2. Recherche des valeurs manquantes :

print(f"Valeurs manquantes : {data.isnull().sum()}")  # Total des valeurs manquantes par colonne
print(f"Valeurs manquantes : {data.isna().sum()}")  # Total des valeurs manquantes par colonne
# Out:
# (10447, 5)
# Valeurs manquantes : rating    0
# id        0
# imdbid    0
# title     0
# year      0
# dtype: int64
# Valeurs manquantes : rating    0
# id        0
# imdbid    0
# title     0
# year      0
# dtype: int64

# %%
# 3. Identification des doublons :

# Doublons de lignes entières
print(data.duplicated().sum())  # Nombre de lignes dupliquées
# Out:
# 0

# %%
# Doublons sur identifiants : 
print(f"Valeurs uniques : {data["imdbid"].unique()}")
print(f"Nombre de ligne par valeur : {data["imdbid"].value_counts()}")

# Récupérer les valeurs pour lesquelles value_counts == 2
imdbid_counts = data["imdbid"].value_counts()
imdbid_with_two_occurrences = imdbid_counts[imdbid_counts >= 2].index.tolist()

# Afficher la liste des valeurs correspondantes
print(f"Liste des valeurs apparaissant 2 fois ou plus : {imdbid_with_two_occurrences}")
# Out:
# Valeurs uniques : ['3155794' '14495706' '2221420' ... '1262426' '31807233' '24176060']
# Nombre de ligne par valeur : imdbid
# 2043900     2
# 0117056     2
#             2
# 0035279     2
# 2457282     2
#            ..
# 0120461     1
# 0118842     1
# 0119859     1
# 0120493     1
# 24176060    1
# Name: count, Length: 10441, dtype: int64
# Liste des valeurs apparaissant 2 fois ou plus : ['2043900', '0117056', '', '0035279', '2457282', '0086425']

# %%
# Focus sur les lignes avec id identique

focus = data[data["imdbid"]=="2457282"]
print(focus)
print(focus["title"][7511])
print(focus["title"][7523])
# Out:
#       rating    id   imdbid  \
# 7517       3  4980  2457282
# 7529       3  5026  2457282
#
#                                                   title  year
# 7517  Puella Magi Madoka Magica the Movie Part III: ...  2013
# 7529                     Madoka Magica: Rebellion Story  2013
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\BigPapaProject\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 7511
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 5
#       3 focus = data[data["imdbid"]=="2457282"]
#       4 print(focus)
# ----> 5 print(focus["title"][7511])
#       6 print(focus["title"][7523])
#
# File d:\BigPapaProject\Anaconda\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File d:\BigPapaProject\Anaconda\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File d:\BigPapaProject\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 7511

# %%
# Focus sur les lignes avec id ''

focus = data[data["imdbid"]==""]
print(focus)
# Out:
#        year                  title     id imdbid  rating
# 5846   2008                 Machan  11315              1
# 10383  2024  A Little Family Drama  11379              3

# %% [markdown]
# ## Actions à mettre en oeuvre
# - supprimer les doublons d'imdbid
# - supprimer les lignes qui ont un imdbid = ''
# - changer le format du 'imdbid' pour avoir tt000000

# %%
# Supprimer les lignes avec doublons sur la colonne 'imdbid' (garder la première occurrence uniquement)

data_bechdel_clean = data.drop_duplicates(subset="imdbid", keep='first')

# Supprimer les lignes avec valeurs '' sur la colonne 'imdbid' 

data_bechdel_clean = data_bechdel_clean[data_bechdel_clean["imdbid"] != '']

# Changer le format du 'imdbid' pour avoir tt000000 

data_bechdel_clean["imdbid"] = 'tt' + data_bechdel_clean["imdbid"]

# Suppression des colonnes 'year', 'title', 'id'

data_bechdel_clean = data_bechdel_clean.drop(['year', 'title', 'id'],axis=1)

# %%
# Voir le résultat : 

display(data_bechdel_clean)
# Out:
#            imdbid  rating
# 0       tt3155794       0
# 1      tt14495706       0
# 2       tt2221420       0
# 3      tt12592084       0
# 4       tt7816420       0
# ...           ...     ...
# 10403  tt15574270       3
# 10404  tt33343397       3
# 10405  tt21187072       3
# 10406  tt17526714       1
# 10407  tt27489557       3
#
# [10401 rows x 2 columns]

# %% [markdown]
# # Étape 3 : Analyse des Variables

# %%
# 2. Variables numériques :

# Statistiques de base et distribution :

for col in data.select_dtypes(include=['int64', 'float64']):
    sns.histplot(data[col], kde=True)
    plt.title(f"Distribution de {col}")
    plt.show()

# %%
# Exporter en CSV

data_bechdel_clean.to_csv('../gitignore/data_bechdel.csv', index=False, encoding='utf-8')
