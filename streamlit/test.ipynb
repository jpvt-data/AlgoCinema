# %%
import streamlit as st
import streamlit_authenticator as stauth
import pandas as pd
from streamlit_option_menu import option_menu
from fuzzywuzzy import process
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import time
import os

df_infos_csv = "../donnees/data/df_info.csv.gz"
df_infos = pd.read_csv(df_infos_csv, compression='infer')
df_infos[df_infos['Titre']=='Inception']
# Out:
# 2024-12-20 17:36:57.209 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-20 17:36:57.217 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-20 17:36:57.223 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-20 17:36:57.227 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-20 17:36:58.902 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# c:\Users\vieas\anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
#            tconst      Titre Titre Original                   genres  \
# 170091  tt1375666  Inception      Inception  Action,Adventure,Sci-Fi
#
#         Année de Sortie  Durée (min)      Note  Nombre Votes  Popularité  \
# 170091             2010          148  8.794438       2614737      77.103
#
#         Décennie  ...  Pays Production     nconst  \
# 170091      2010  ...     ['GB', 'US']  nm0634240
#
#                                       Slogan  \
# 170091  Your mind is the scene of the crime.
#
#                                                  Synopsis  \
# 170091  Cobb, a skilled thief who commits corporate es...
#
#                           Chemin Affiche                Chemin Affiche Pub  \
# 170091  /edv5CZvWj09upOsy2Y6IwDhK8bt.jpg  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg
#
#                                            Url Site Langue Originale  \
# 170091  https://www.warnerbros.com/movies/inception               en
#
#                  Langues Parlées    Statut
# 170091  ['en', 'fr', 'ja', 'sw']  Released
#
# [1 rows x 22 columns]
