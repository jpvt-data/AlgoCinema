# %%
import pandas as pd

# %% [markdown]
# Chargement des bases de données

# %%
# TmdB tmdb.full
tmdb = pd.read_csv("../gitignore/tmdb_info_final.csv")

# %%
# Data Bechdel
bechdel = pd.read_csv("'../gitignore/data_bechdel.csv'")

# %%
# ImdB name.basics
name = pd.read_csv('../gitignore/name.basics_info_film_final.tsv', sep="\t")
