# %%
import pandas as pd

# %%
file_path_episodes = "../exploration/BIG_DF.ipynb"

db01 = pd.read_csv("../gitignore/title_basics_traite.csv")
db02 = pd.read_csv("../gitignore/title.akas_final.tsv")
db03 = pd.read_csv("../gitignore/title.ratings.tsv", sep="\t")
db04 = pd.read_csv("../gitignore/title.principals4.tsv", sep="\t")
db05 = pd.read_csv("../gitignore/name.basics.tsv", sep="\t")
db06 = pd.read_csv("../gitignore/title.crew.tsv", sep="\t") # Ne pas utiliser pour le ML
db07 = pd.read_csv("../gitignore/data_bechdel.csv")
db08 = pd.read_csv("../gitignore/tmdb_final.csv")
# Out:
# C:\Users\frale\AppData\Local\Temp\ipykernel_33404\1670471252.py:9: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   db07 = pd.read_csv("../gitignore/tmdb_final.csv")

# %%
db01_tot = db01.shape[0]
print(f"Total: {db01_tot}")
db01.nunique()
# Out:
# Total: 361533
# tconst            361533
# titleType             10
# primaryTitle      340797
# originalTitle     340985
# isAdult                1
# startYear            100
# endYear               34
# runtimeMinutes       466
# genres               298
# decade                13
# dtype: int64

# %%
db02_tot = db02.shape[0]
print(f"Total: {db02_tot}")
db02.nunique()
# Out:
# Total: 1500950
# tconst           1500950
# averageRating         91
# numVotes           22785
# dtype: int64

# %%
dbmerge_1 = pd.merge(db02, db01, on='tconst', how='left')

# %%
display(dbmerge_1.head())
# Out:
#       tconst  averageRating  numVotes titleType primaryTitle originalTitle  \
# 0  tt0000001            5.7      2101       NaN          NaN           NaN
# 1  tt0000002            5.6       282       NaN          NaN           NaN
# 2  tt0000003            6.5      2121       NaN          NaN           NaN
# 3  tt0000004            5.4       182       NaN          NaN           NaN
# 4  tt0000005            6.2      2852       NaN          NaN           NaN
#
#   isAdult  startYear  endYear  runtimeMinutes genres  decade
# 0     NaN        NaN      NaN             NaN    NaN     NaN
# 1     NaN        NaN      NaN             NaN    NaN     NaN
# 2     NaN        NaN      NaN             NaN    NaN     NaN
# 3     NaN        NaN      NaN             NaN    NaN     NaN
# 4     NaN        NaN      NaN             NaN    NaN     NaN

# %%
dbmerge_1_tot = dbmerge_1.shape[0]
print(f"Total: {dbmerge_1_tot}")
dbmerge_1.nunique()
# Out:
# Total: 1500950
# tconst            1500950
# averageRating          91
# numVotes            22785
# titleType              10
# primaryTitle        22561
# originalTitle       22607
# isAdult                 1
# startYear              78
# endYear                27
# runtimeMinutes        337
# genres                234
# decade                 13
# dtype: int64

# %%
db03_tot = db03.shape[0]
print(f"Total: {db03_tot}")
db03.nunique()
# Out:
# Total: 75327831
# tconst             10086702
# nconst              5751717
# category                  6
# job                   40970
# characters          4148522
# plusieurs_roles           2
# dtype: int64

# %%
dbmerge_2 = pd.merge(dbmerge_1, db03, on='tconst', how='left')

# %%
display(dbmerge_2.head())
# Out:
#       tconst  averageRating  numVotes titleType primaryTitle originalTitle  \
# 0  tt0000001            5.7      2101       NaN          NaN           NaN
# 1  tt0000001            5.7      2101       NaN          NaN           NaN
# 2  tt0000001            5.7      2101       NaN          NaN           NaN
# 3  tt0000002            5.6       282       NaN          NaN           NaN
# 4  tt0000003            6.5      2121       NaN          NaN           NaN
#
#   isAdult  startYear  endYear  runtimeMinutes genres  decade     nconst  \
# 0     NaN        NaN      NaN             NaN    NaN     NaN  nm1588970
# 1     NaN        NaN      NaN             NaN    NaN     NaN  nm0005690
# 2     NaN        NaN      NaN             NaN    NaN     NaN  nm0005690
# 3     NaN        NaN      NaN             NaN    NaN     NaN  nm0721526
# 4     NaN        NaN      NaN             NaN    NaN     NaN  nm0721526
#
#    category       job characters plusieurs_roles
# ...

# %%
dbmerge_2_tot = dbmerge_2.shape[0]
print(f"Total: {dbmerge_2_tot}")
dbmerge_2.nunique()
# Out:
# Total: 16763332
# tconst             1500950
# averageRating           91
# numVotes             22785
# titleType               10
# primaryTitle         22561
# originalTitle        22607
# isAdult                  1
# startYear               78
# endYear                 27
# runtimeMinutes         337
# genres                 234
# decade                  13
# nconst             2367392
# category                 6
# job                  27515
# characters         2426303
# plusieurs_roles          2
# dtype: int64

# %%
db04_tot = db04.shape[0]
print(f"Total: {db04_tot}")
db04.nunique()
# Out:
# Total: 13958409
# nconst               13958409
# primaryName          10719045
# birthYear                 544
# deathYear                 487
# primaryProfession       23082
# knownForTitles        5814340
# dtype: int64

# %%
dbmerge_3 = pd.merge(dbmerge_2, db04, on='nconst', how='left')

# %%
display(dbmerge_3.head())
# Out:
#       tconst  averageRating  numVotes titleType primaryTitle originalTitle  \
# 0  tt0000001            5.7      2101       NaN          NaN           NaN
# 1  tt0000001            5.7      2101       NaN          NaN           NaN
# 2  tt0000001            5.7      2101       NaN          NaN           NaN
# 3  tt0000002            5.6       282       NaN          NaN           NaN
# 4  tt0000003            6.5      2121       NaN          NaN           NaN
#
#   isAdult  startYear  endYear  runtimeMinutes  ...     nconst  category  \
# 0     NaN        NaN      NaN             NaN  ...  nm1588970      self
# 1     NaN        NaN      NaN             NaN  ...  nm0005690  director
# 2     NaN        NaN      NaN             NaN  ...  nm0005690  producer
# 3     NaN        NaN      NaN             NaN  ...  nm0721526  director
# 4     NaN        NaN      NaN             NaN  ...  nm0721526  director
#
#         job characters plusieurs_roles           primaryName birthYear  \
# ...

# %%
dbmerge_3_tot = dbmerge_3.shape[0]
print(f"Total: {dbmerge_3_tot}")
dbmerge_3.nunique()
# Out:
# Total: 16763332
# tconst               1500950
# averageRating             91
# numVotes               22785
# titleType                 10
# primaryTitle           22561
# originalTitle          22607
# isAdult                    1
# startYear                 78
# endYear                   27
# runtimeMinutes           337
# genres                   234
# decade                    13
# nconst               2367392
# category                   6
# job                    27515
# characters           2426303
# plusieurs_roles            2
# primaryName          2136496
# birthYear                408
# deathYear                350
# primaryProfession      13161
# knownForTitles       1832384
# dtype: int64

# %%
db05_tot = db05.shape[0]
print(f"Total: {db05_tot}")
db05.nunique()
# Out:
# Total: 10582976
# tconst       10582976
# directors      928981
# writers       1381497
# dtype: int64

# %%
dbmerge_4 = pd.merge(db05, dbmerge_3, on='tconst', how='left')

# %%
display(dbmerge_4.head())
# Out:
#       tconst  directors writers  averageRating  numVotes titleType  \
# 0  tt0000001  nm0005690      \N            5.7    2101.0       NaN
# 1  tt0000001  nm0005690      \N            5.7    2101.0       NaN
# 2  tt0000001  nm0005690      \N            5.7    2101.0       NaN
# 3  tt0000002  nm0721526      \N            5.6     282.0       NaN
# 4  tt0000003  nm0721526      \N            6.5    2121.0       NaN
#
#   primaryTitle originalTitle isAdult  startYear  ...     nconst  category  \
# 0          NaN           NaN     NaN        NaN  ...  nm1588970      self
# 1          NaN           NaN     NaN        NaN  ...  nm0005690  director
# 2          NaN           NaN     NaN        NaN  ...  nm0005690  producer
# 3          NaN           NaN     NaN        NaN  ...  nm0721526  director
# 4          NaN           NaN     NaN        NaN  ...  nm0721526  director
#
#         job  characters plusieurs_roles           primaryName birthYear  \
# ...

# %%
dbmerge_4_tot = dbmerge_4.shape[0]
print(f"Total: {dbmerge_4_tot}")
dbmerge_4.nunique()
# Out:
# Total: 25845358
# tconst               10582976
# directors              928981
# writers               1381497
# averageRating              91
# numVotes                22784
# titleType                  10
# primaryTitle            22462
# originalTitle           22509
# isAdult                     1
# startYear                  69
# endYear                    27
# runtimeMinutes            337
# genres                    234
# decade                     12
# nconst                2367392
# category                    6
# job                     27515
# characters            2426303
# plusieurs_roles             2
# primaryName           2136496
# birthYear                 408
# deathYear                 350
# primaryProfession       13161
# knownForTitles        1832384
# dtype: int64

# %%
db06_tot = db06.shape[0]
print(f"Total: {db06_tot}")
db06.nunique()
# Out:
# Total: 10401
# year        143
# title     10134
# id        10401
# imdbid    10401
# rating        4
# dtype: int64

# %%
dbmerge_5 = pd.merge(dbmerge_4, db06, left_on='tconst', right_on='imdbid', how='left')

# %%
display(dbmerge_5.head())
# Out:
#       tconst  directors writers  averageRating  numVotes titleType  \
# 0  tt0000001  nm0005690      \N            5.7    2101.0       NaN
# 1  tt0000001  nm0005690      \N            5.7    2101.0       NaN
# 2  tt0000001  nm0005690      \N            5.7    2101.0       NaN
# 3  tt0000002  nm0721526      \N            5.6     282.0       NaN
# 4  tt0000003  nm0721526      \N            6.5    2121.0       NaN
#
#   primaryTitle originalTitle isAdult  startYear  ...           primaryName  \
# 0          NaN           NaN     NaN        NaN  ...            Carmencita
# 1          NaN           NaN     NaN        NaN  ...  William K.L. Dickson
# 2          NaN           NaN     NaN        NaN  ...  William K.L. Dickson
# 3          NaN           NaN     NaN        NaN  ...         Émile Reynaud
# 4          NaN           NaN     NaN        NaN  ...         Émile Reynaud
#
#    birthYear deathYear                       primaryProfession  \
# ...

# %%
dbmerge_5_tot = dbmerge_5.shape[0]
print(f"Total: {dbmerge_5_tot}")
dbmerge_5.nunique()
# Out:
# Total: 25845358
# tconst               10582976
# directors              928981
# writers               1381497
# averageRating              91
# numVotes                22784
# titleType                  10
# primaryTitle            22462
# originalTitle           22509
# isAdult                     1
# startYear                  69
# endYear                    27
# runtimeMinutes            337
# genres                    234
# decade                     12
# nconst                2367392
# category                    6
# job                     27515
# characters            2426303
# plusieurs_roles             2
# primaryName           2136496
# birthYear                 408
# deathYear                 350
# primaryProfession       13161
# knownForTitles        1832384
# year                      143
# title                   10129
# id                      10393
# imdbid                  10393
# rating                      4
# dtype: int64

# %%
db07_tot = db07.shape[0]
print(f"Total: {db07_tot}")
db07.nunique()
# Out:
# Total: 714175
# adult                                1
# backdrop_path                   151556
# budget                            3597
# genres                              19
# homepage                         43233
# id                              309571
# imdb_id                         309571
# original_language                  152
# original_title                  284591
# overview                        280954
# popularity                       18297
# poster_path                     263741
# production_countries               231
# release_date                       145
# revenue                          12865
# runtime                            460
# spoken_languages                   177
# status                               6
# tagline                          73633
# title                           271999
# video                                2
# vote_average                      4732
# vote_count                        3560
# production_companies_name       112932
# ...

# %%
dbmerge_6 = pd.merge(dbmerge_5, db07, left_on='tconst', right_on='imdb_id', how='left')

# %%
display(dbmerge_6.head())
# Out:
#       tconst  directors writers  averageRating  numVotes titleType  \
# 0  tt0000001  nm0005690      \N            5.7    2101.0       NaN
# 1  tt0000001  nm0005690      \N            5.7    2101.0       NaN
# 2  tt0000001  nm0005690      \N            5.7    2101.0       NaN
# 3  tt0000002  nm0721526      \N            5.6     282.0       NaN
# 4  tt0000003  nm0721526      \N            6.5    2121.0       NaN
#
#   primaryTitle originalTitle isAdult  startYear  ...  runtime  \
# 0          NaN           NaN     NaN        NaN  ...      1.0
# 1          NaN           NaN     NaN        NaN  ...      1.0
# 2          NaN           NaN     NaN        NaN  ...      1.0
# 3          NaN           NaN     NaN        NaN  ...     10.0
# 4          NaN           NaN     NaN        NaN  ...      4.0
#
#    spoken_languages    status  tagline             title_y  video  \
# 0                xx  Released      NaN          Carmencita  False
# ...

# %%
display(dbmerge_6.sample(15))
# Out:
#               tconst            directors  \
# 10234475  tt10910004                   \N
# 3206237    tt0176734            nm0003313
# 3231978    tt0179599            nm0868932
# 30506243   tt9028376  nm6515289,nm5842181
# 7058576    tt0653722            nm0446060
# 16943442   tt1740012            nm0535734
# 12925659  tt13136356  nm2388373,nm0765795
# 16557306   tt1669904            nm0120046
# 10588231  tt11173026                   \N
# 22967955   tt3158886            nm5918064
# 2133679    tt0101692            nm0747724
# 11265732  tt11711686                   \N
# 8838830    tt0954388            nm0589929
# 17038653   tt1756714            nm1577190
# 24662860   tt3823442            nm1842601
#
#                                                     writers  averageRating  \
# 10234475                                          nm0345998            NaN
# 3206237                                           nm0791630            6.2
# ...

# %%
dbmerge_6_tot = dbmerge_6.shape[0]
print(f"Total: {dbmerge_6_tot}")
dbmerge_6.nunique()
# Out:
# Total: 31325443
# tconst                          10582976
# directors                         928981
# writers                          1381497
# averageRating                         91
# numVotes                           22784
# titleType                             10
# primaryTitle                       22462
# originalTitle                      22509
# isAdult                                1
# startYear                             69
# endYear                               27
# runtimeMinutes                       337
# genres_x                             234
# decade                                12
# nconst                           2367392
# category                               6
# job                                27515
# characters                       2426303
# plusieurs_roles                        2
# primaryName                      2136496
# birthYear                            408
# deathYear                            350
# ...

# %%
# dbmerge_1.to_csv("dbmerge_1.csv", index=False)

# %%
# dbmerge_3.to_csv("dbmerge_3.csv", index=False)

# %%
# dbmerge_6.to_csv("big_df.csv", index=False)
# 10GB
